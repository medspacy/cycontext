# %%
import os, sys, glob
import spacy
import pandas as pd

from spacy.pipeline import EntityRuler

# %%
sys.path.append('..')

# %%
from cycontext.item_data import ItemData
from cycontext.tag_object import TagObject
from cycontext.context_component import ConTextComponent

# %%
# %load_ext autoreload
# %autoreload 2

# %%
nlp = spacy.load("en_core_web_sm")
_ = nlp.remove_pipe("ner")

# %% [markdown]
# # Overview
# - Read in data
# - Read in modifiers

# %% [markdown]
# # I. Read in Knowledge Base

# %% [markdown]
# ## I.I Targets

# %%
targets_filepath = os.path.join(".", "pneumonia", "kb", "pneumonia_targets.tsv")
targets_df = pd.read_csv(targets_filepath, sep="\t")

# %%
targets_df.head()
# Out:
#              Lex                   Type                Regex  Direction  Codes
# 0      pneumonia  EVIDENCE_OF_PNEUMONIA          pneumonias?        NaN    NaN
# 1  consolidation  EVIDENCE_OF_PNEUMONIA                  NaN        NaN    NaN
# 2     infiltrate  EVIDENCE_OF_PNEUMONIA  infiltrat(e|es|ion)        NaN    NaN
# 3       effusion  EVIDENCE_OF_PNEUMONIA             effusion        NaN    NaN

# %%
target_patterns = []
for i, row in targets_df.fillna('').iterrows():
    literal = row["Lex"]
    category = row["Type"]
    regex = row["Regex"]
    
    if regex == '':
        pattern = [{"LOWER": literal}]
    else:
        pattern = [{"LOWER": {"REGEX": regex}}]
    target_patterns.append({"label": category, "pattern": pattern})

# %%
# Use the EntityRuler class for rule-based NER
ruler = EntityRuler(nlp, overwrite_ents=True)
ruler.add_patterns(target_patterns)

# %%
try:
    _ = nlp.remove_pipe("entity_ruler")
except:
    pass
nlp.add_pipe(ruler)

# %% [markdown]
# ## I.II Modifiers

# %%
tsv_mods = pd.read_csv(os.path.join('.', "pneumonia", "kb", "pneumonia_modifiers.tsv"), sep="\t")

# %%
mod_patterns = []
for i, row in tsv_mods.fillna("").iterrows():
    d = {"literal": row["Lex"],
        "category": row["Type"],
        "pattern": row["Regex"],
        "rule": row["Direction"]}
    if d["pattern"] == "":
        d["pattern"] = None
    else:
        d["pattern"] = [d["pattern"]]
    mod_patterns.append(d)

# %%
import json

# %%
data = {"patterns": mod_patterns}

# %%
outpath = os.path.join(".", "pneumonia", "kb", "pneumonia_modifiers.json")
# with open(outpath, "w") as f:
#     json.dump(data, f, indent=4)

# %%
with open(outpath) as f:
    modifier_data = json.load(f)

# %%
modifier_data
# Out:
# {'patterns': [{'literal': 'are ruled out',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'be ruled out',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'being ruled out',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'can be ruled out',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'cannot be excluded',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'cannot totally be excluded',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'could be ruled out',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'examination',
#    'category': 'INDICATION',
#    'pattern': [{'LOWER': {'REGEX': '(examination|exam|study)'}}],
#    'rule': 'backward'},
#   {'literal': 'free',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'has been ruled out',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'have been ruled out',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'is in the differential',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': [{'LOWER': 'is'},
#     {'LOWER': 'in'},
#     {'LOWER': 'the'},
#     {'LOWER': 'differential'}],
#    'rule': 'backward'},
#   {'literal': 'is negative',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': [{'LEMMA': 'be'}, {'LOWER': 'negative'}],
#    'rule': 'backward'},
#   {'literal': 'is not excluded',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': [{'LEMMA': 'be'}, {'LOWER': 'not'}, {'LOWER': 'excluded'}],
#    'rule': 'backward'},
#   {'literal': 'is not entirely excluded',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': [{'LEMMA': 'be'},
#     {'LOWER': 'not'},
#     {'LOWER': {'IN': ['entirely', 'definitely', 'completely']}},
#     {'LOWER': 'excluded'}],
#    'rule': 'backward'},
#   {'literal': 'is present',
#    'category': 'DEFINITE_EXISTENCE',
#    'pattern': [{'LEMMA': 'be'}, {'LOWER': 'present'}],
#    'rule': 'backward'},
#   {'literal': 'is ruled out',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'is to be ruled out',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'is ruled out',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'might be ruled out',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'must be ruled out',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'not been ruled out',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'not definitively seen',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': [{'LOWER': 'not'},
#     {'LOWER': 'definitively'},
#     {'LOWER': {'IN': ['seen', 'visualized']}}],
#    'rule': 'backward'},
#   {'literal': 'not excluded',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': [{'LOWER': 'not'}, {'LOWER': 'excluded'}],
#    'rule': 'backward'},
#   {'literal': 'not excluded',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': [{'LOWER': 'not'}, {'LOWER': 'ruled'}, {'LOWER': 'out'}],
#    'rule': 'backward'},
#   {'literal': 'now measuring',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'ought to be ruled out',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'progressed',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'protocol',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'resolved',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'should be ruled out',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'reason for this examination',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'reason',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'suspected',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'unlikely',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'varying ages',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'was ruled out',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'will be ruled out',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'would not be expected',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'acute',
#    'category': 'ACUTE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'again',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'age indeterminate',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'appear',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': [{'LEMMA': 'appear'}],
#    'rule': 'bidirectional'},
#   {'literal': 'cannot be completely excluded',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': [{'LOWER': 'cannot'},
#     {'LOWER': 'be'},
#     {'LOWER': {'IN': ['entirely', 'completely', 'totally']}},
#     {'LOWER': 'ruled'},
#     {'LOWER': 'out'}],
#    'rule': 'bidirectional'},
#   {'literal': 'cannot be completely excluded',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': [{'LOWER': 'cannot'},
#     {'LOWER': 'be'},
#     {'LOWER': {'IN': ['entirely', 'completely', 'totally']}},
#     {'LOWER': 'excluded'}],
#    'rule': 'bidirectional'},
#   {'literal': 'cannot be evaluated',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'chronic',
#    'category': 'HISTORICAL',
#    'pattern': [{'LOWER': {'REGEX': 'chronic'}}],
#    'rule': 'bidirectional'},
#   {'literal': 'clear',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'diminished',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'equivocal',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'evaluation',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'evolving',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'healing',
#    'category': 'HISTORICAL',
#    'pattern': [{'LEMMA': 'heal'}],
#    'rule': 'bidirectional'},
#   {'literal': 'improved',
#    'category': 'HISTORICAL',
#    'pattern': [{'LOWER': {'IN': ['improved', 'improving', 'improvemenet']}}],
#    'rule': 'bidirectional'},
#   {'literal': 'incompletely evaluated',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'interval change',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'interval increase',
#    'category': 'HISTORICAL',
#    'pattern': [{'LOWER': 'interval'}, {'LOWER': 'increase'}],
#    'rule': 'bidirectional'},
#   {'literal': 'less likely',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'likely',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'likely chronic',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'may be ruled out',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'new',
#    'category': 'ACUTE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'new from prior exam',
#    'category': 'ACUTE',
#    'pattern': [{'LOWER': 'new'},
#     {'LOWER': 'from'},
#     {'LOWER': 'the', 'OP': '?'},
#     {'LOWER': 'prior'},
#     {'LOWER': {'IN': ['exam', 'study']}}],
#    'rule': 'bidirectional'},
#   {'literal': 'no change in',
#    'category': 'HISTORICAL',
#    'pattern': [{'LOWER': {'REGEX': 'not?'}},
#     {'IS_ALPHA': True, 'OP': '?'},
#     {'LEMMA': 'change'},
#     {'LOWER': 'in', 'OP': '?'}],
#    'rule': 'bidirectional'},
#   {'literal': 'no longer noted',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': [{'LOWER': 'no'},
#     {'LOWER': 'longer'},
#     {'LOWER': {'IN': ['seen', 'noted', 'visualized']}}],
#    'rule': 'bidirectional'},
#   {'literal': 'not',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'not significantly changed',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'old',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'on previous exam',
#    'category': 'HISTORICAL',
#    'pattern': [{'LOWER': {'IN': ['on', 'from']}},
#     {'LOWER': {'IN': ['previous', 'prior']}},
#     {'LEMMA': 'exam'}],
#    'rule': 'bidirectional'},
#   {'literal': 'persistent',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'possible',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'previous',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'previously described',
#    'category': 'HISTORICAL',
#    'pattern': [{'LOWER': 'previously'},
#     {'LOWER': {'IN': ['described', 'suspected']}}],
#    'rule': 'bidirectional'},
#   {'literal': 'prior',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'prior study',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'probable',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'questionable',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'ruled out',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'should be considered',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'stable',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'still evident',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'subacute',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'suggest',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': [{'LEMMA': 'suggest'}],
#    'rule': 'bidirectional'},
#   {'literal': 'unchanged',
#    'category': 'HISTORICAL',
#    'pattern': [{'LOWER': {'IN': ['unchanged', 'unchaning']}}],
#    'rule': 'bidirectional'},
#   {'literal': 'versus',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'absence of',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'adequate to rule the patient out',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'appears to be',
#    'category': 'DEFINITE_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'assessment for',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'at risk for',
#    'category': 'FUTURE',
#    'pattern': [{'LOWER': 'at'},
#     {'LOWER': 'risk'},
#     {'LOWER': {'IN': ['for', 'of']}}],
#    'rule': 'forward'},
#   {'literal': 'at risk for',
#    'category': 'FUTURE',
#    'pattern': [{'LOWER': 'at'},
#     {'LOWER': 'risk'},
#     {'LOWER': 'in'},
#     {'LOWER': 'the'},
#     {'LOWER': 'future'},
#     {'LOWER': {'IN': ['for', 'of']}}],
#    'rule': 'forward'},
#   {'literal': 'atypical for',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'be ruled out for',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'can be ruled out for',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'can rule the patient out',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': [{'LOWER': 'can'},
#     {'LOWER': 'rule'},
#     {'LOWER': {'IN': ['her', 'him']}},
#     {'LOWER': 'out'}],
#    'rule': 'forward'},
#   {'literal': 'can rule the patient out',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': [{'LOWER': 'can'},
#     {'LOWER': 'rule'},
#     {'LOWER': 'the'},
#     {'LOWER': 'patient'},
#     {'LOWER': 'out'}],
#    'rule': 'forward'},
#   {'literal': 'cannot',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'cannot exclude',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'cannot see',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'cannot totally exclude',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'change in',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'changing',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'checked for',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'clinical concern',
#    'category': 'FUTURE',
#    'pattern': [{'LEMMA': 'clinical'},
#     {'LEMMA': {'IN': ['concern', 'suspicion']}}],
#    'rule': 'forward'},
#   {'literal': 'clinical history',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'compatible with',
#    'category': 'DEFINITE_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'concerning for',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'consistent with',
#    'category': 'DEFINITE_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'convincing',
#    'category': 'DEFINITE_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'could be ruled out for',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'declined',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'declines',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'decrease in',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'decrease in',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'definite',
#    'category': 'DEFINITE_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'denied',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'denies',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'deny',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'denying',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'did rule (the patient|him|her) out',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': [{'LOWER': 'did'},
#     {'LOWER': 'rule'},
#     {'LOWER': {'IN': ['him', 'her']}},
#     {'LOWER': 'out'}],
#    'rule': 'forward'},
#   {'literal': 'did rule (the patient|him|her) out',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': [{'LOWER': 'did'},
#     {'LOWER': 'rule'},
#     {'LOWER': 'the'},
#     {'LOWER': 'patient'},
#     {'LOWER': 'out'}],
#    'rule': 'forward'},
#   {'literal': 'did rule out',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'differential diagnosis would include',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': [{'LOWER': 'differential'},
#     {'LOWER': {'IN': ['diagnosis', 'considerations']}, 'OP': '?'},
#     {'LOWER': {'IN': ['would', 'could']}},
#     {'LEMMA': 'include'}],
#    'rule': 'forward'},
#   {'literal': 'documented',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'evaluate for',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'evaluation of',
#    'category': 'INDICATION',
#    'pattern': [{'LEMMA': 'evaluation'}, {'LOWER': {'IN': ['of', 'for']}}],
#    'rule': 'forward'},
#   {'literal': 'evidence',
#    'category': 'DEFINITE_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'did rule her out against',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'examination for',
#    'category': 'INDICATION',
#    'pattern': [{'LOWER': {'IN': ['study', 'exam', 'examination']}},
#     {'LOWER': 'for'}],
#    'rule': 'forward'},
#   {'literal': 'fails to reveal',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'free of',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'gram negative',
#    'category': 'PSEUDONEG',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'higher sensitivity for',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'highly suggestive',
#    'category': 'DEFINITE_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'history of',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'if there are',
#    'category': 'FUTURE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'if there is concern for',
#    'category': 'FUTURE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'is to be ruled out for',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'is more sensitive',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'known',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'low probability',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'may be related',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'may represent',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': [{'LEMMA': 'may'}, {'LOWER': {'IN': ['represent', 'reflect']}}],
#    'rule': 'forward'},
#   {'literal': 'might be ruled out for',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'mimicking',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'must be ruled out for',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'negative examination for',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': [{'LOWER': 'negative'},
#     {'LOWER': {'IN': ['examination', 'study', 'exam', 'evaluation']}},
#     {'LOWER': 'for'}],
#    'rule': 'forward'},
#   {'literal': 'negative for',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'never developed',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'never had',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'no',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'no abnormal',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'no cause of',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'no complaints of',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'no convincing',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'no definite',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'no definite change',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'no evidence of',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': [{'LOWER': {'IN': ['no', 'without']}},
#     {'LOWER': {'IN': ['definite',
#        'other',
#        'definitive',
#        'secondary',
#        'indirect']}},
#     {'LOWER': {'IN': ['radiographic', 'sonographic', 'ct']}, 'OP': '?'},
#     {'LOWER': 'evidence'},
#     {'LOWER': {'IN': ['of', 'for']}}],
#    'rule': 'forward'},
#   {'literal': 'no findings of',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'no findings to indicate',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'no increase',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'no new',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'no obvious',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'no other',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'no sign of',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'no significant',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'no significant change',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'no significant interval change',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'no signs',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': [{'LOWER': 'no'}, {'LEMMA': 'sign'}],
#    'rule': 'forward'},
#   {'literal': 'no definite signs of',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': [{'LOWER': {'IN': ['no', 'without']}},
#     {'LOWER': {'IN': ['definite',
#        'other',
#        'definitive',
#        'secondary',
#        'indirect']}},
#     {'LOWER': {'IN': ['radiographic', 'sonographic', 'ct']}, 'OP': '?'},
#     {'LEMMA': 'sign'},
#     {'LOWER': {'IN': ['of', 'for']}}],
#    'rule': 'forward'},
#   {'literal': 'no suggestion',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'no suspicious change',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'no XYZ to suggest',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': [{'LOWER': {'IN': ['without', 'no']}},
#     {'OP': '*'},
#     {'LOWER': 'to'},
#     {'LOWER': 'suggest'}],
#    'rule': 'forward'},
#   {'literal': 'nor',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'not appreciate',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'not associated with',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'not cause',
#    'category': 'PSEUDONEG',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'not certain whether',
#    'category': 'PSEUDONEG',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'not clearly evident',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'not complain of',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'not demonstrate',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'not drain',
#    'category': 'PSEUDONEG',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'not exhibit',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'not extend',
#    'category': 'PSEUDONEG',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'not feel',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'not had',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'not have',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'not know of',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'not known to have',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'not necessarily',
#    'category': 'PSEUDONEG',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'not reveal',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'not see',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'not to be',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'nothing',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'obvious',
#    'category': 'DEFINITE_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'ought to be ruled out for',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'patient was not',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'positive study for',
#    'category': 'DEFINITE_EXISTENCE',
#    'pattern': [{'LOWER': 'positive'},
#     {'LOWER': {'IN': ['study', 'exam', 'examination']}},
#     {'LOWER': 'for'}],
#    'rule': 'forward'},
#   {'literal': 'predispose to ',
#    'category': 'FUTURE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'progression of',
#    'category': 'HISTORICAL',
#    'pattern': [{'LOWER': 'progression'}, {'LOWER': {'IN': ['of', 'in']}}],
#    'rule': 'forward'},
#   {'literal': 'rather than',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'redemonstration',
#    'category': 'HISTORICAL',
#    'pattern': [{'LOWER': {'REGEX': 're-?demonstrat'}}],
#    'rule': 'forward'},
#   {'literal': 'remote',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'represents',
#    'category': 'DEFINITE_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'residual',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'resolution of',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'resolving',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'rule her out',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'rule him out',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'rule him out for',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'rule out',
#    'category': 'INDICATION',
#    'pattern': [{'LOWER': 'r/o'}],
#    'comment': '// TODO: Does this match as one token?',
#    'rule': 'forward'},
#   {'literal': 'rule out',
#    'category': 'INDICATION',
#    'pattern': [{'LOWER': 'rule'}, {'LOWER': 'out'}],
#    'comment': ' TODO: (r/o|rule out|\\br o\\b|r\\.o\\.|\\bro\\b)',
#    'rule': 'forward'},
#   {'literal': 'rule out for',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'rule patient out for',
#    'category': 'INDICATION',
#    'pattern': [{'LOWER': 'rule'},
#     {'LOWER': 'the', 'OP': '?'},
#     {'LOWER': {'IN': ['him', 'her', 'patient', 'subject']}},
#     {'LOWER': 'out'},
#     {'LOWER': 'for'}],
#    'comment': 'rule (him|her|patient|the patient|subject) out for',
#    'rule': 'forward'},
#   {'literal': 'rule the patient out',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'rule the patient out for',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'rule patient out for',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': [{'LOWER': 'ruled'},
#     {'LOWER': 'the', 'OP': '?'},
#     {'LOWER': {'IN': ['him', 'her', 'patient', 'subject']}},
#     {'LOWER': 'out'},
#     {'LOWER': {'IN': ['for', 'against']}}],
#    'comment': 'ruled\\s(him|her|the subject|the patient|subject|patient)\\sout( against| for)?',
#    'rule': 'forward'},
#   {'literal': 'ruled out against',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'ruled out for',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'rules her out',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'rules her out for',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': [{'LOWER': 'rules'},
#     {'LOWER': {'IN': ['him', 'her']}},
#     {'LOWER': 'out'},
#     {'LOWER': 'for', 'OP': '?'}],
#    'rule': 'forward'},
#   {'literal': 'rules out',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'rules out for',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'rules the patient out',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'rules the patient out for',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'sequelae of',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'should be ruled out for',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'simulating',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'study for detection',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'sufficient to rule out',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': [{'LOWER': 'sufficient'},
#     {'LOWER': 'to'},
#     {'LOWER': 'rule'},
#     {'LOWER': 'the', 'OP': '?'},
#     {'LOWER': {'IN': ['him', 'her', 'patient', 'subject']}, 'OP': '?'},
#     {'LOWER': 'out'}],
#    'comment': 'sufficient\\sto\\srule\\s((her|him|the patient|the subject)\\s)?out',
#    'rule': 'forward'},
#   {'literal': 'suspicious',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'suspicous',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'test for',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'to exclude',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'unable to adequately assess',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'unable to assess',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'unremarkable for',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'warned of',
#    'category': 'FUTURE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'were warned',
#    'category': 'FUTURE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'what must be ruled out is',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'will be ruled out for',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'with no',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'without',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'without difficulty',
#    'category': 'PSEUDONEG',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'without indication',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'without sign',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': [{'LOWER': 'without'}, {'LEMMA': 'sign'}],
#    'rule': 'forward'},
#   {'literal': 'worrisome',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': '#NAME?',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'although',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'apart from',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as a cause for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as a cause of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as a etiology for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as a etiology of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as a reason for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as a reason of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as a secondary cause for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as a secondary cause of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as a secondary etiology for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as a secondary etiology of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as a secondary origin for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as a secondary origin of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as a secondary reason for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as a secondary reason of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as a secondary source for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as a secondary source of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as a source for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as a source of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as an cause for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as an cause of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as an etiology for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as an etiology of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as an origin for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as an origin of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as an reason for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as an reason of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as an secondary cause for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as an secondary cause of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as an secondary etiology for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as an secondary etiology of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as an secondary origin for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as an secondary origin of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as an secondary reason for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as an secondary reason of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as an secondary source for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as an secondary source of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as an source for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as an source of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as the cause for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as the cause of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as the etiology for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as the etiology of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as the origin for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as the origin of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as the reason for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as the reason of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as the secondary cause for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as the secondary cause of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as the secondary etiology for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as the secondary etiology of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as the secondary origin for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as the secondary origin of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as the secondary reason for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as the secondary reason of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as the secondary source for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as the secondary source of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as the source for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as the source of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'as there are ',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'aside from',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'but', 'category': 'CONJ', 'pattern': None, 'rule': 'terminate'},
#   {'literal': 'cause for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'cause of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'causes for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'causes of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'etiology for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'etiology of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'except',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'however',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'involving',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'nevertheless',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'origin for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'origin of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'origins for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'origins of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'other possibilities of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'reason for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'reason of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'reasons for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'reasons of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'secondary to',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'source for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'source of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'sources for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'sources of',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'still',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'though',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'trigger event for',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'which',
#    'category': 'CONJ',
#    'pattern': None,
#    'rule': 'terminate'},
#   {'literal': 'yet', 'category': 'CONJ', 'pattern': None, 'rule': 'terminate'},
#   {'literal': '(no|nothing) convincing',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': '(the patient|him|her) was not',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'as a suggestion',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'associated with',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'believe',
#    'category': 'DEFINITE_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'borderline',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'can rule out',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'can rule out against',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'can rule out for',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'can see',
#    'category': 'DEFINITE_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'cannot rule out',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': [{'LOWER': 'cannot'},
#     {'LOWER': 'rule'},
#     {'LOWER': 'the', 'OP': '?'},
#     {'LOWER': {'IN': ['patient', 'him', 'her']}, 'OP': '?'},
#     {'LOWER': 'out'}],
#    'rule': 'forward'},
#   {'literal': 'completely excluded',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': [{'LOWER': {'IN': ['completely', 'entirely']}, 'OP': '?'},
#     {'LOWER': 'excluded'}],
#    'rule': 'backward'},
#   {'literal': 'construed as',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'could be',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'could not be ruled',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'could represent',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'equivocal',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'every indication',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'excluded',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'exhibit',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'gross evidence',
#    'category': 'DEFINITE_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'high probability',
#    'category': 'DEFINITE_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'highly hesitant',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'indication',
#    'category': 'INDICATION',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'insufficient to rule (the patient|him|her) out for',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'is positive',
#    'category': 'DEFINITE_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'no other (CT|radiographic|sonographic|MR|etc) evidence',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'no secondary (CT|radiographic|sonographic|MR|etc) signs',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'no suspicious',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'not adequate to rule out',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': [{'LOWER': 'not'},
#     {'LOWER': 'adequate'},
#     {'LOWER': 'to'},
#     {'LOWER': 'rule'},
#     {'LOWER': 'the', 'OP': '?'},
#     {'LOWER': {'IN': ['patient', 'him', 'her']}, 'OP': '?'},
#     {'LOWER': 'out'}],
#    'rule': 'forward'},
#   {'literal': 'not likely',
#    'category': 'DEFINITE_NEGATED_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'not only',
#    'category': 'PSEUDONEG',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'reveals',
#    'category': 'DEFINITE_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'seen best',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'signs of',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'},
#   {'literal': 'was not excluded',
#    'category': 'AMBIVALENT_EXISTENCE',
#    'pattern': [{'LOWER': {'IN': ['was', 'were']}},
#     {'LOWER': 'not'},
#     {'LOWER': 'excluded'}],
#    'rule': 'backward'},
#   {'literal': 'if',
#    'category': 'HYPOTHETICAL',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'decrease',
#    'category': 'HISTORICAL',
#    'pattern': [{'LEMMA': {'IN': ['decrease',
#        'increase',
#        'reduce',
#        'reduction']}}],
#    'rule': 'bidirectional'},
#   {'literal': 'increase',
#    'category': 'HISTORICAL',
#    'pattern': [{'LEMMA': 'increase'}],
#    'rule': 'bidirectional'},
#   {'literal': 'possibly',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'decrease the likelihood',
#    'category': 'PROBABLE_NEGATED_EXISTENCE',
#    'pattern': [{'LEMMA': 'decrease'},
#     {'LOWER': 'the', 'OP': '?'},
#     {'LOWER': 'likelihood'}],
#    'rule': 'forward'},
#   {'literal': 'suspect',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': None,
#    'rule': 'forward'},
#   {'literal': 'likely represents',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': [{'LOWER': 'likely'}, {'LEMMA': 'represent'}],
#    'rule': 'forward'},
#   {'literal': 'without change',
#    'category': 'HISTORICAL',
#    'pattern': None,
#    'rule': 'backward'},
#   {'literal': 'risk factor',
#    'category': 'FUTURE',
#    'pattern': [{'LOWER': 'risk'}, {'LEMMA': 'factor'}],
#    'rule': 'bidirectional'},
#   {'literal': 'favor',
#    'category': 'PROBABLE_EXISTENCE',
#    'pattern': None,
#    'rule': 'bidirectional'}]}

# %%
item_data = []
for data in modifier_data["patterns"]:
    item = ItemData(**data)
    item_data.append(item)

# %%
item_data
# Out:
# [ItemData: [are ruled out, definite_negated_existence, None, backward],
#  ItemData: [be ruled out, indication, None, backward],
#  ItemData: [being ruled out, indication, None, backward],
#  ItemData: [can be ruled out, definite_negated_existence, None, backward],
#  ItemData: [cannot be excluded, ambivalent_existence, None, backward],
#  ItemData: [cannot totally be excluded, probable_negated_existence, None, backward],
#  ItemData: [could be ruled out, definite_negated_existence, None, backward],
#  ItemData: [examination, indication, [{'LOWER': {'REGEX': '(examination|exam|study)'}}], backward],
#  ItemData: [free, definite_negated_existence, None, backward],
#  ItemData: [has been ruled out, definite_negated_existence, None, backward],
#  ItemData: [have been ruled out, definite_negated_existence, None, backward],
#  ItemData: [is in the differential, ambivalent_existence, [{'LOWER': 'is'}, {'LOWER': 'in'}, {'LOWER': 'the'}, {'LOWER': 'differential'}], backward],
#  ItemData: [is negative, definite_negated_existence, [{'LEMMA': 'be'}, {'LOWER': 'negative'}], backward],
#  ItemData: [is not excluded, ambivalent_existence, [{'LEMMA': 'be'}, {'LOWER': 'not'}, {'LOWER': 'excluded'}], backward],
#  ItemData: [is not entirely excluded, probable_negated_existence, [{'LEMMA': 'be'}, {'LOWER': 'not'}, {'LOWER': {'IN': ['entirely', 'definitely', 'completely']}}, {'LOWER': 'excluded'}], backward],
#  ItemData: [is present, definite_existence, [{'LEMMA': 'be'}, {'LOWER': 'present'}], backward],
#  ItemData: [is ruled out, definite_negated_existence, None, backward],
#  ItemData: [is to be ruled out, indication, None, backward],
#  ItemData: [is ruled out, definite_negated_existence, None, backward],
#  ItemData: [might be ruled out, probable_negated_existence, None, backward],
#  ItemData: [must be ruled out, definite_negated_existence, None, backward],
#  ItemData: [not been ruled out, indication, None, backward],
#  ItemData: [not definitively seen, probable_negated_existence, [{'LOWER': 'not'}, {'LOWER': 'definitively'}, {'LOWER': {'IN': ['seen', 'visualized']}}], backward],
#  ItemData: [not excluded, ambivalent_existence, [{'LOWER': 'not'}, {'LOWER': 'excluded'}], backward],
#  ItemData: [not excluded, ambivalent_existence, [{'LOWER': 'not'}, {'LOWER': 'ruled'}, {'LOWER': 'out'}], backward],
#  ItemData: [now measuring, historical, None, backward],
#  ItemData: [ought to be ruled out, indication, None, backward],
#  ItemData: [progressed, historical, None, backward],
#  ItemData: [protocol, indication, None, backward],
#  ItemData: [resolved, historical, None, backward],
#  ItemData: [should be ruled out, indication, None, backward],
#  ItemData: [reason for this examination, indication, None, forward],
#  ItemData: [reason, indication, None, forward],
#  ItemData: [suspected, probable_existence, None, backward],
#  ItemData: [unlikely, definite_negated_existence, None, bidirectional],
#  ItemData: [varying ages, historical, None, backward],
#  ItemData: [was ruled out, definite_negated_existence, None, backward],
#  ItemData: [will be ruled out, indication, None, backward],
#  ItemData: [would not be expected, probable_negated_existence, None, backward],
#  ItemData: [acute, acute, None, bidirectional],
#  ItemData: [again, historical, None, bidirectional],
#  ItemData: [age indeterminate, historical, None, bidirectional],
#  ItemData: [appear, probable_existence, [{'LEMMA': 'appear'}], bidirectional],
#  ItemData: [cannot be completely excluded, probable_negated_existence, [{'LOWER': 'cannot'}, {'LOWER': 'be'}, {'LOWER': {'IN': ['entirely', 'completely', 'totally']}}, {'LOWER': 'ruled'}, {'LOWER': 'out'}], bidirectional],
#  ItemData: [cannot be completely excluded, probable_negated_existence, [{'LOWER': 'cannot'}, {'LOWER': 'be'}, {'LOWER': {'IN': ['entirely', 'completely', 'totally']}}, {'LOWER': 'excluded'}], bidirectional],
#  ItemData: [cannot be evaluated, ambivalent_existence, None, bidirectional],
#  ItemData: [chronic, historical, [{'LOWER': {'REGEX': 'chronic'}}], bidirectional],
#  ItemData: [clear, probable_negated_existence, None, bidirectional],
#  ItemData: [diminished, historical, None, bidirectional],
#  ItemData: [equivocal, probable_existence, None, bidirectional],
#  ItemData: [evaluation, indication, None, bidirectional],
#  ItemData: [evolving, historical, None, bidirectional],
#  ItemData: [healing, historical, [{'LEMMA': 'heal'}], bidirectional],
#  ItemData: [improved, historical, [{'LOWER': {'IN': ['improved', 'improving', 'improvemenet']}}], bidirectional],
#  ItemData: [incompletely evaluated, ambivalent_existence, None, bidirectional],
#  ItemData: [interval change, historical, None, bidirectional],
#  ItemData: [interval increase, historical, [{'LOWER': 'interval'}, {'LOWER': 'increase'}], bidirectional],
#  ItemData: [less likely, ambivalent_existence, None, bidirectional],
#  ItemData: [likely, probable_existence, None, bidirectional],
#  ItemData: [likely chronic, historical, None, bidirectional],
#  ItemData: [may be ruled out, definite_negated_existence, None, bidirectional],
#  ItemData: [new, acute, None, bidirectional],
#  ItemData: [new from prior exam, acute, [{'LOWER': 'new'}, {'LOWER': 'from'}, {'LOWER': 'the', 'OP': '?'}, {'LOWER': 'prior'}, {'LOWER': {'IN': ['exam', 'study']}}], bidirectional],
#  ItemData: [no change in, historical, [{'LOWER': {'REGEX': 'not?'}}, {'IS_ALPHA': True, 'OP': '?'}, {'LEMMA': 'change'}, {'LOWER': 'in', 'OP': '?'}], bidirectional],
#  ItemData: [no longer noted, definite_negated_existence, [{'LOWER': 'no'}, {'LOWER': 'longer'}, {'LOWER': {'IN': ['seen', 'noted', 'visualized']}}], bidirectional],
#  ItemData: [not, definite_negated_existence, None, bidirectional],
#  ItemData: [not significantly changed, historical, None, bidirectional],
#  ItemData: [old, historical, None, bidirectional],
#  ItemData: [on previous exam, historical, [{'LOWER': {'IN': ['on', 'from']}}, {'LOWER': {'IN': ['previous', 'prior']}}, {'LEMMA': 'exam'}], bidirectional],
#  ItemData: [persistent, historical, None, bidirectional],
#  ItemData: [possible, probable_existence, None, bidirectional],
#  ItemData: [previous, historical, None, bidirectional],
#  ItemData: [previously described, historical, [{'LOWER': 'previously'}, {'LOWER': {'IN': ['described', 'suspected']}}], bidirectional],
#  ItemData: [prior, historical, None, bidirectional],
#  ItemData: [prior study, historical, None, bidirectional],
#  ItemData: [probable, probable_existence, None, bidirectional],
#  ItemData: [questionable, probable_negated_existence, None, bidirectional],
#  ItemData: [ruled out, definite_negated_existence, None, bidirectional],
#  ItemData: [should be considered, probable_existence, None, bidirectional],
#  ItemData: [stable, historical, None, bidirectional],
#  ItemData: [still evident, historical, None, bidirectional],
#  ItemData: [subacute, historical, None, bidirectional],
#  ItemData: [suggest, probable_existence, [{'LEMMA': 'suggest'}], bidirectional],
#  ItemData: [unchanged, historical, [{'LOWER': {'IN': ['unchanged', 'unchaning']}}], bidirectional],
#  ItemData: [versus, ambivalent_existence, None, bidirectional],
#  ItemData: [absence of, definite_negated_existence, None, forward],
#  ItemData: [adequate to rule the patient out, definite_negated_existence, None, forward],
#  ItemData: [appears to be, definite_existence, None, forward],
#  ItemData: [assessment for, indication, None, forward],
#  ItemData: [at risk for, future, [{'LOWER': 'at'}, {'LOWER': 'risk'}, {'LOWER': {'IN': ['for', 'of']}}], forward],
#  ItemData: [at risk for, future, [{'LOWER': 'at'}, {'LOWER': 'risk'}, {'LOWER': 'in'}, {'LOWER': 'the'}, {'LOWER': 'future'}, {'LOWER': {'IN': ['for', 'of']}}], forward],
#  ItemData: [atypical for, probable_negated_existence, None, forward],
#  ItemData: [be ruled out for, indication, None, forward],
#  ItemData: [can be ruled out for, definite_negated_existence, None, forward],
#  ItemData: [can rule the patient out, definite_negated_existence, [{'LOWER': 'can'}, {'LOWER': 'rule'}, {'LOWER': {'IN': ['her', 'him']}}, {'LOWER': 'out'}], forward],
#  ItemData: [can rule the patient out, definite_negated_existence, [{'LOWER': 'can'}, {'LOWER': 'rule'}, {'LOWER': 'the'}, {'LOWER': 'patient'}, {'LOWER': 'out'}], forward],
#  ItemData: [cannot, ambivalent_existence, None, forward],
#  ItemData: [cannot exclude, ambivalent_existence, None, forward],
#  ItemData: [cannot see, ambivalent_existence, None, forward],
#  ItemData: [cannot totally exclude, probable_negated_existence, None, forward],
#  ItemData: [change in, historical, None, forward],
#  ItemData: [changing, historical, None, forward],
#  ItemData: [checked for, probable_existence, None, forward],
#  ItemData: [clinical concern, future, [{'LEMMA': 'clinical'}, {'LEMMA': {'IN': ['concern', 'suspicion']}}], forward],
#  ItemData: [clinical history, historical, None, forward],
#  ItemData: [compatible with, definite_existence, None, forward],
#  ItemData: [concerning for, probable_existence, None, forward],
#  ItemData: [consistent with, definite_existence, None, forward],
#  ItemData: [convincing, definite_existence, None, forward],
#  ItemData: [could be ruled out for, definite_negated_existence, None, forward],
#  ItemData: [declined, definite_negated_existence, None, forward],
#  ItemData: [declines, probable_negated_existence, None, forward],
#  ItemData: [decrease in, historical, None, forward],
#  ItemData: [decrease in, historical, None, forward],
#  ItemData: [definite, definite_existence, None, forward],
#  ItemData: [denied, probable_negated_existence, None, forward],
#  ItemData: [denies, probable_negated_existence, None, forward],
#  ItemData: [deny, probable_negated_existence, None, forward],
#  ItemData: [denying, probable_negated_existence, None, forward],
#  ItemData: [did rule (the patient|him|her) out, definite_negated_existence, [{'LOWER': 'did'}, {'LOWER': 'rule'}, {'LOWER': {'IN': ['him', 'her']}}, {'LOWER': 'out'}], forward],
#  ItemData: [did rule (the patient|him|her) out, definite_negated_existence, [{'LOWER': 'did'}, {'LOWER': 'rule'}, {'LOWER': 'the'}, {'LOWER': 'patient'}, {'LOWER': 'out'}], forward],
#  ItemData: [did rule out, definite_negated_existence, None, forward],
#  ItemData: [differential diagnosis would include, ambivalent_existence, [{'LOWER': 'differential'}, {'LOWER': {'IN': ['diagnosis', 'considerations']}, 'OP': '?'}, {'LOWER': {'IN': ['would', 'could']}}, {'LEMMA': 'include'}], forward],
#  ItemData: [documented, historical, None, forward],
#  ItemData: [evaluate for, indication, None, forward],
#  ItemData: [evaluation of, indication, [{'LEMMA': 'evaluation'}, {'LOWER': {'IN': ['of', 'for']}}], forward],
#  ItemData: [evidence, definite_existence, None, forward],
#  ItemData: [did rule her out against, definite_negated_existence, None, forward],
#  ItemData: [examination for, indication, [{'LOWER': {'IN': ['study', 'exam', 'examination']}}, {'LOWER': 'for'}], forward],
#  ItemData: [fails to reveal, definite_negated_existence, None, forward],
#  ItemData: [free of, definite_negated_existence, None, forward],
#  ItemData: [gram negative, pseudoneg, None, forward],
#  ItemData: [higher sensitivity for, indication, None, forward],
#  ItemData: [highly suggestive, definite_existence, None, forward],
#  ItemData: [history of, historical, None, forward],
#  ItemData: [if there are, future, None, forward],
#  ItemData: [if there is concern for, future, None, forward],
#  ItemData: [is to be ruled out for, indication, None, forward],
#  ItemData: [is more sensitive, indication, None, forward],
#  ItemData: [known, historical, None, forward],
#  ItemData: [low probability, probable_negated_existence, None, forward],
#  ItemData: [may be related, probable_existence, None, forward],
#  ItemData: [may represent, probable_existence, [{'LEMMA': 'may'}, {'LOWER': {'IN': ['represent', 'reflect']}}], forward],
#  ItemData: [might be ruled out for, probable_negated_existence, None, forward],
#  ItemData: [mimicking, probable_negated_existence, None, forward],
#  ItemData: [must be ruled out for, definite_negated_existence, None, forward],
#  ItemData: [negative examination for, definite_negated_existence, [{'LOWER': 'negative'}, {'LOWER': {'IN': ['examination', 'study', 'exam', 'evaluation']}}, {'LOWER': 'for'}], forward],
#  ItemData: [negative for, definite_negated_existence, None, forward],
#  ItemData: [never developed, probable_negated_existence, None, forward],
#  ItemData: [never had, definite_negated_existence, None, forward],
#  ItemData: [no, definite_negated_existence, None, forward],
#  ItemData: [no abnormal, definite_negated_existence, None, forward],
#  ItemData: [no cause of, probable_negated_existence, None, forward],
#  ItemData: [no complaints of, ambivalent_existence, None, forward],
#  ItemData: [no convincing, probable_negated_existence, None, forward],
#  ItemData: [no definite, definite_negated_existence, None, forward],
#  ItemData: [no definite change, historical, None, forward],
#  ItemData: [no evidence of, definite_negated_existence, [{'LOWER': {'IN': ['no', 'without']}}, {'LOWER': {'IN': ['definite', 'other', 'definitive', 'secondary', 'indirect']}}, {'LOWER': {'IN': ['radiographic', 'sonographic', 'ct']}, 'OP': '?'}, {'LOWER': 'evidence'}, {'LOWER': {'IN': ['of', 'for']}}], forward],
#  ItemData: [no findings of, probable_negated_existence, None, forward],
#  ItemData: [no findings to indicate, definite_negated_existence, None, forward],
#  ItemData: [no increase, historical, None, forward],
#  ItemData: [no new, definite_negated_existence, None, forward],
#  ItemData: [no obvious, probable_negated_existence, None, forward],
#  ItemData: [no other, probable_negated_existence, None, forward],
#  ItemData: [no sign of, probable_negated_existence, None, forward],
#  ItemData: [no significant, probable_negated_existence, None, forward],
#  ItemData: [no significant change, historical, None, forward],
#  ItemData: [no significant interval change, historical, None, forward],
#  ItemData: [no signs, definite_negated_existence, [{'LOWER': 'no'}, {'LEMMA': 'sign'}], forward],
#  ItemData: [no definite signs of, probable_negated_existence, [{'LOWER': {'IN': ['no', 'without']}}, {'LOWER': {'IN': ['definite', 'other', 'definitive', 'secondary', 'indirect']}}, {'LOWER': {'IN': ['radiographic', 'sonographic', 'ct']}, 'OP': '?'}, {'LEMMA': 'sign'}, {'LOWER': {'IN': ['of', 'for']}}], forward],
#  ItemData: [no suggestion, definite_negated_existence, None, forward],
#  ItemData: [no suspicious change, historical, None, forward],
#  ItemData: [no XYZ to suggest, definite_negated_existence, [{'LOWER': {'IN': ['without', 'no']}}, {'OP': '*'}, {'LOWER': 'to'}, {'LOWER': 'suggest'}], forward],
#  ItemData: [nor, probable_negated_existence, None, forward],
#  ItemData: [not appreciate, probable_negated_existence, None, forward],
#  ItemData: [not associated with, probable_negated_existence, None, forward],
#  ItemData: [not cause, pseudoneg, None, forward],
#  ItemData: [not certain whether, pseudoneg, None, forward],
#  ItemData: [not clearly evident, probable_negated_existence, None, forward],
#  ItemData: [not complain of, probable_negated_existence, None, forward],
#  ItemData: [not demonstrate, definite_negated_existence, None, forward],
#  ItemData: [not drain, pseudoneg, None, forward],
#  ItemData: [not exhibit, definite_negated_existence, None, forward],
#  ItemData: [not extend, pseudoneg, None, forward],
#  ItemData: [not feel, probable_negated_existence, None, forward],
#  ItemData: [not had, definite_negated_existence, None, forward],
#  ItemData: [not have, definite_negated_existence, None, forward],
#  ItemData: [not know of, ambivalent_existence, None, forward],
#  ItemData: [not known to have, ambivalent_existence, None, forward],
#  ItemData: [not necessarily, pseudoneg, None, forward],
#  ItemData: [not reveal, definite_negated_existence, None, forward],
#  ItemData: [not see, definite_negated_existence, None, forward],
#  ItemData: [not to be, probable_negated_existence, None, forward],
#  ItemData: [nothing, probable_negated_existence, None, forward],
#  ItemData: [obvious, definite_existence, None, forward],
#  ItemData: [ought to be ruled out for, indication, None, forward],
#  ItemData: [patient was not, definite_negated_existence, None, forward],
#  ItemData: [positive study for, definite_existence, [{'LOWER': 'positive'}, {'LOWER': {'IN': ['study', 'exam', 'examination']}}, {'LOWER': 'for'}], forward],
#  ItemData: [predispose to , future, None, forward],
#  ItemData: [progression of, historical, [{'LOWER': 'progression'}, {'LOWER': {'IN': ['of', 'in']}}], forward],
#  ItemData: [rather than, probable_existence, None, forward],
#  ItemData: [redemonstration, historical, [{'LOWER': {'REGEX': 're-?demonstrat'}}], forward],
#  ItemData: [remote, historical, None, forward],
#  ItemData: [represents, definite_existence, None, forward],
#  ItemData: [residual, historical, None, forward],
#  ItemData: [resolution of, historical, None, forward],
#  ItemData: [resolving, historical, None, forward],
#  ItemData: [rule her out, indication, None, forward],
#  ItemData: [rule him out, indication, None, forward],
#  ItemData: [rule him out for, indication, None, forward],
#  ItemData: [rule out, indication, [{'LOWER': 'r/o'}], forward],
#  ItemData: [rule out, indication, [{'LOWER': 'rule'}, {'LOWER': 'out'}], forward],
#  ItemData: [rule out for, indication, None, forward],
#  ItemData: [rule patient out for, indication, [{'LOWER': 'rule'}, {'LOWER': 'the', 'OP': '?'}, {'LOWER': {'IN': ['him', 'her', 'patient', 'subject']}}, {'LOWER': 'out'}, {'LOWER': 'for'}], forward],
#  ItemData: [rule the patient out, indication, None, forward],
#  ItemData: [rule the patient out for, indication, None, forward],
#  ItemData: [rule patient out for, definite_negated_existence, [{'LOWER': 'ruled'}, {'LOWER': 'the', 'OP': '?'}, {'LOWER': {'IN': ['him', 'her', 'patient', 'subject']}}, {'LOWER': 'out'}, {'LOWER': {'IN': ['for', 'against']}}], forward],
#  ItemData: [ruled out against, definite_negated_existence, None, forward],
#  ItemData: [ruled out for, definite_negated_existence, None, forward],
#  ItemData: [rules her out, definite_negated_existence, None, forward],
#  ItemData: [rules her out for, definite_negated_existence, [{'LOWER': 'rules'}, {'LOWER': {'IN': ['him', 'her']}}, {'LOWER': 'out'}, {'LOWER': 'for', 'OP': '?'}], forward],
#  ItemData: [rules out, definite_negated_existence, None, forward],
#  ItemData: [rules out for, definite_negated_existence, None, forward],
#  ItemData: [rules the patient out, definite_negated_existence, None, forward],
#  ItemData: [rules the patient out for, definite_negated_existence, None, forward],
#  ItemData: [sequelae of, historical, None, forward],
#  ItemData: [should be ruled out for, indication, None, forward],
#  ItemData: [simulating, probable_negated_existence, None, forward],
#  ItemData: [study for detection, indication, None, forward],
#  ItemData: [sufficient to rule out, definite_negated_existence, [{'LOWER': 'sufficient'}, {'LOWER': 'to'}, {'LOWER': 'rule'}, {'LOWER': 'the', 'OP': '?'}, {'LOWER': {'IN': ['him', 'her', 'patient', 'subject']}, 'OP': '?'}, {'LOWER': 'out'}], forward],
#  ItemData: [suspicious, probable_existence, None, forward],
#  ItemData: [suspicous, probable_existence, None, forward],
#  ItemData: [test for, ambivalent_existence, None, forward],
#  ItemData: [to exclude, probable_negated_existence, None, forward],
#  ItemData: [unable to adequately assess, ambivalent_existence, None, forward],
#  ItemData: [unable to assess, ambivalent_existence, None, forward],
#  ItemData: [unremarkable for, definite_negated_existence, None, forward],
#  ItemData: [warned of, future, None, forward],
#  ItemData: [were warned, future, None, forward],
#  ItemData: [what must be ruled out is, indication, None, forward],
#  ItemData: [will be ruled out for, indication, None, forward],
#  ItemData: [with no, definite_negated_existence, None, forward],
#  ItemData: [without, definite_negated_existence, None, forward],
#  ItemData: [without difficulty, pseudoneg, None, forward],
#  ItemData: [without indication, probable_negated_existence, None, forward],
#  ItemData: [without sign, definite_negated_existence, [{'LOWER': 'without'}, {'LEMMA': 'sign'}], forward],
#  ItemData: [worrisome, probable_existence, None, forward],
#  ItemData: [#NAME?, definite_negated_existence, None, forward],
#  ItemData: [although, conj, None, terminate],
#  ItemData: [apart from, conj, None, terminate],
#  ItemData: [as a cause for, conj, None, terminate],
#  ItemData: [as a cause of, conj, None, terminate],
#  ItemData: [as a etiology for, conj, None, terminate],
#  ItemData: [as a etiology of, conj, None, terminate],
#  ItemData: [as a reason for, conj, None, terminate],
#  ItemData: [as a reason of, conj, None, terminate],
#  ItemData: [as a secondary cause for, conj, None, terminate],
#  ItemData: [as a secondary cause of, conj, None, terminate],
#  ItemData: [as a secondary etiology for, conj, None, terminate],
#  ItemData: [as a secondary etiology of, conj, None, terminate],
#  ItemData: [as a secondary origin for, conj, None, terminate],
#  ItemData: [as a secondary origin of, conj, None, terminate],
#  ItemData: [as a secondary reason for, conj, None, terminate],
#  ItemData: [as a secondary reason of, conj, None, terminate],
#  ItemData: [as a secondary source for, conj, None, terminate],
#  ItemData: [as a secondary source of, conj, None, terminate],
#  ItemData: [as a source for, conj, None, terminate],
#  ItemData: [as a source of, conj, None, terminate],
#  ItemData: [as an cause for, conj, None, terminate],
#  ItemData: [as an cause of, conj, None, terminate],
#  ItemData: [as an etiology for, conj, None, terminate],
#  ItemData: [as an etiology of, conj, None, terminate],
#  ItemData: [as an origin for, conj, None, terminate],
#  ItemData: [as an origin of, conj, None, terminate],
#  ItemData: [as an reason for, conj, None, terminate],
#  ItemData: [as an reason of, conj, None, terminate],
#  ItemData: [as an secondary cause for, conj, None, terminate],
#  ItemData: [as an secondary cause of, conj, None, terminate],
#  ItemData: [as an secondary etiology for, conj, None, terminate],
#  ItemData: [as an secondary etiology of, conj, None, terminate],
#  ItemData: [as an secondary origin for, conj, None, terminate],
#  ItemData: [as an secondary origin of, conj, None, terminate],
#  ItemData: [as an secondary reason for, conj, None, terminate],
#  ItemData: [as an secondary reason of, conj, None, terminate],
#  ItemData: [as an secondary source for, conj, None, terminate],
#  ItemData: [as an secondary source of, conj, None, terminate],
#  ItemData: [as an source for, conj, None, terminate],
#  ItemData: [as an source of, conj, None, terminate],
#  ItemData: [as the cause for, conj, None, terminate],
#  ItemData: [as the cause of, conj, None, terminate],
#  ItemData: [as the etiology for, conj, None, terminate],
#  ItemData: [as the etiology of, conj, None, terminate],
#  ItemData: [as the origin for, conj, None, terminate],
#  ItemData: [as the origin of, conj, None, terminate],
#  ItemData: [as the reason for, conj, None, terminate],
#  ItemData: [as the reason of, conj, None, terminate],
#  ItemData: [as the secondary cause for, conj, None, terminate],
#  ItemData: [as the secondary cause of, conj, None, terminate],
#  ItemData: [as the secondary etiology for, conj, None, terminate],
#  ItemData: [as the secondary etiology of, conj, None, terminate],
#  ItemData: [as the secondary origin for, conj, None, terminate],
#  ItemData: [as the secondary origin of, conj, None, terminate],
#  ItemData: [as the secondary reason for, conj, None, terminate],
#  ItemData: [as the secondary reason of, conj, None, terminate],
#  ItemData: [as the secondary source for, conj, None, terminate],
#  ItemData: [as the secondary source of, conj, None, terminate],
#  ItemData: [as the source for, conj, None, terminate],
#  ItemData: [as the source of, conj, None, terminate],
#  ItemData: [as there are , conj, None, terminate],
#  ItemData: [aside from, conj, None, terminate],
#  ItemData: [but, conj, None, terminate],
#  ItemData: [cause for, conj, None, terminate],
#  ItemData: [cause of, conj, None, terminate],
#  ItemData: [causes for, conj, None, terminate],
#  ItemData: [causes of, conj, None, terminate],
#  ItemData: [etiology for, conj, None, terminate],
#  ItemData: [etiology of, conj, None, terminate],
#  ItemData: [except, conj, None, terminate],
#  ItemData: [however, conj, None, terminate],
#  ItemData: [involving, conj, None, terminate],
#  ItemData: [nevertheless, conj, None, terminate],
#  ItemData: [origin for, conj, None, terminate],
#  ItemData: [origin of, conj, None, terminate],
#  ItemData: [origins for, conj, None, terminate],
#  ItemData: [origins of, conj, None, terminate],
#  ItemData: [other possibilities of, conj, None, terminate],
#  ItemData: [reason for, conj, None, terminate],
#  ItemData: [reason of, conj, None, terminate],
#  ItemData: [reasons for, conj, None, terminate],
#  ItemData: [reasons of, conj, None, terminate],
#  ItemData: [secondary to, conj, None, terminate],
#  ItemData: [source for, conj, None, terminate],
#  ItemData: [source of, conj, None, terminate],
#  ItemData: [sources for, conj, None, terminate],
#  ItemData: [sources of, conj, None, terminate],
#  ItemData: [still, conj, None, terminate],
#  ItemData: [though, conj, None, terminate],
#  ItemData: [trigger event for, conj, None, terminate],
#  ItemData: [which, conj, None, terminate],
#  ItemData: [yet, conj, None, terminate],
#  ItemData: [(no|nothing) convincing, definite_negated_existence, None, forward],
#  ItemData: [(the patient|him|her) was not, definite_negated_existence, None, forward],
#  ItemData: [as a suggestion, probable_existence, None, bidirectional],
#  ItemData: [associated with, probable_existence, None, forward],
#  ItemData: [believe, definite_existence, None, bidirectional],
#  ItemData: [borderline, ambivalent_existence, None, bidirectional],
#  ItemData: [can rule out, definite_negated_existence, None, forward],
#  ItemData: [can rule out against, definite_negated_existence, None, forward],
#  ItemData: [can rule out for, definite_negated_existence, None, forward],
#  ItemData: [can see, definite_existence, None, forward],
#  ItemData: [cannot rule out, ambivalent_existence, [{'LOWER': 'cannot'}, {'LOWER': 'rule'}, {'LOWER': 'the', 'OP': '?'}, {'LOWER': {'IN': ['patient', 'him', 'her']}, 'OP': '?'}, {'LOWER': 'out'}], forward],
#  ItemData: [completely excluded, definite_negated_existence, [{'LOWER': {'IN': ['completely', 'entirely']}, 'OP': '?'}, {'LOWER': 'excluded'}], backward],
#  ItemData: [construed as, probable_existence, None, bidirectional],
#  ItemData: [could be, probable_existence, None, forward],
#  ItemData: [could not be ruled, ambivalent_existence, None, bidirectional],
#  ItemData: [could represent, probable_existence, None, forward],
#  ItemData: [equivocal, ambivalent_existence, None, bidirectional],
#  ItemData: [every indication, probable_existence, None, forward],
#  ItemData: [excluded, definite_negated_existence, None, backward],
#  ItemData: [exhibit, probable_existence, None, bidirectional],
#  ItemData: [gross evidence, definite_existence, None, forward],
#  ItemData: [high probability, definite_existence, None, bidirectional],
#  ItemData: [highly hesitant, ambivalent_existence, None, bidirectional],
#  ItemData: [indication, indication, None, bidirectional],
#  ItemData: [insufficient to rule (the patient|him|her) out for, ambivalent_existence, None, forward],
#  ItemData: [is positive, definite_existence, None, bidirectional],
#  ItemData: [no other (CT|radiographic|sonographic|MR|etc) evidence, probable_negated_existence, None, forward],
#  ItemData: [no secondary (CT|radiographic|sonographic|MR|etc) signs, probable_negated_existence, None, forward],
#  ItemData: [no suspicious, probable_negated_existence, None, forward],
#  ItemData: [not adequate to rule out, ambivalent_existence, [{'LOWER': 'not'}, {'LOWER': 'adequate'}, {'LOWER': 'to'}, {'LOWER': 'rule'}, {'LOWER': 'the', 'OP': '?'}, {'LOWER': {'IN': ['patient', 'him', 'her']}, 'OP': '?'}, {'LOWER': 'out'}], forward],
#  ItemData: [not likely, definite_negated_existence, None, bidirectional],
#  ItemData: [not only, pseudoneg, None, forward],
#  ItemData: [reveals, definite_existence, None, forward],
#  ItemData: [seen best, probable_existence, None, backward],
#  ItemData: [signs of, probable_existence, None, bidirectional],
#  ItemData: [was not excluded, ambivalent_existence, [{'LOWER': {'IN': ['was', 'were']}}, {'LOWER': 'not'}, {'LOWER': 'excluded'}], backward],
#  ItemData: [if, hypothetical, None, forward],
#  ItemData: [decrease, historical, [{'LEMMA': {'IN': ['decrease', 'increase', 'reduce', 'reduction']}}], bidirectional],
#  ItemData: [increase, historical, [{'LEMMA': 'increase'}], bidirectional],
#  ItemData: [possibly, probable_existence, None, forward],
#  ItemData: [decrease the likelihood, probable_negated_existence, [{'LEMMA': 'decrease'}, {'LOWER': 'the', 'OP': '?'}, {'LOWER': 'likelihood'}], forward],
#  ItemData: [suspect, probable_existence, None, forward],
#  ItemData: [likely represents, probable_existence, [{'LOWER': 'likely'}, {'LEMMA': 'represent'}], forward],
#  ItemData: [without change, historical, None, backward],
#  ItemData: [risk factor, future, [{'LOWER': 'risk'}, {'LEMMA': 'factor'}], bidirectional],
#  ItemData: [favor, probable_existence, None, bidirectional]]

# %% [markdown]
# # II. Read Data

# %%
txt_files = glob.glob(os.path.join(".", "pneumonia", "training_v2", "*.txt"))

# %%
texts = []
for file in txt_files:
    texts.append(open(file).read())

# %% [markdown]
# # III. Process with NLP

# %% [markdown]
# ## III.II Add ConText

# %%
context = ConTextComponent(item_data, nlp)

# %%
try:
    nlp.add_pipe(context)
except:
    nlp.remove_pipe("context")
    nlp.add_pipe(context)

# %% [markdown]
# ### III.I Custom sentence segmentation
# The spaCy default works poorly with MIMIC data. Should eventually replace with PyRUSH.

# %%
from nltk.tokenize import PunktSentenceTokenizer

# %%
def set_custom_boundaries(doc, tokenizer):
    sent_spans = tokenizer.span_tokenize(doc.text)
    for token in doc:
        token.is_sent_start = False
    for (start, end) in sent_spans:
        sent = doc.char_span(start, end)
        sent[0].is_sent_start = True
    return doc

# %%
try:
    nlp.remove_pipe('set_custom_boundaries')
except:
    pass
nlp.add_pipe(set_custom_boundaries, before="parser")

# %%
tokenizer = PunktSentenceTokenizer()

# %%
cfg = {'set_custom_boundaries': {"tokenizer": tokenizer}}

# %%
doc = nlp(texts[12], component_cfg=cfg)

for sent in doc.sents:
    print("---", sent)
    print()
# Out:
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [Increased, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# ---
#
#
#      DATE: [**2919-8-31**] 5:14 PM
#      CHEST (PA & LAT)                                                Clip # [**Clip Number (Radiology) 11222**]
#      Reason: infiltrate vs.
#
# --- pulmonary edema
#      ______________________________________________________________________________
#      UNDERLYING MEDICAL CONDITION:
#       50 year old man with cough and hemoptysis and now progressive O2 requirement,
#       signs of CHF on exam.
#
# --- PMH of MVR.
#
#
# --- REASON FOR THIS EXAMINATION:
#       infiltrate vs.
#
# --- pulmonary edema
#      ______________________________________________________________________________
#                                      FINAL REPORT
#      INDICATIONS:  Cough and hemoptysis.
#
#
#
# --- PA AND LATERAL CHEST:  Comparison is made to previous films from  [**2919-8-17**].
#
#
# --- The patient has prior MBR and median sternotomy.
#
#
#
# --- Note is made of increased nodular and linear opacities involving the right
#      upper lobe and left lower lobe.
#
# --- In this patient with HIV and history of
#      chemotherapy for seminoma, these findings are worrisome for chronic infection
#      including fungus or microbacterial infection.
#
# --- Further evaluation with CT scan
#      is recommended.
#
# --- There is slight prominence of the left hilum.
#
# --- The patchy
#      opacity in the left lower lobe could represent bronchopneumonia.
#
# --- The heart
#      is normal in size.
#
# --- There is no evidence for CHF.
#
# --- No pneumothorax is
#      identified.
#
#
#
# --- IMPRESSION:  Increased nausea and linear opacities involving the right upper
#      lobe and left lower lobe, please see comment for discussion.

# %% [markdown]
# ## 3.3 Process documents

# %%
nlp.pipeline
# Out:
# [('tagger', <spacy.pipeline.pipes.Tagger at 0x11f85e7f0>),
#  ('set_custom_boundaries',
#   <function __main__.set_custom_boundaries(doc, tokenizer)>),
#  ('parser', <spacy.pipeline.pipes.DependencyParser at 0x12a9aed08>),
#  ('context', <cycontext.context_component.ConTextComponent at 0x126868c88>)]

# %%
docs = list(nlp.pipe(texts, component_cfg=cfg))
# Out:
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [increased, historical]
#
# <TagObject> [excluded, definite_negated_existence]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [no definite, definite_negated_existence]
#
# <TagObject> [No significant, probable_negated_existence]
#
# <TagObject> [No significant interval change, historical]
#
# <TagObject> [No significant interval change, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [no definite, definite_negated_existence]
#
# <TagObject> [No significant interval change, historical]
#
# <TagObject> [No significant interval change, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [no definite, definite_negated_existence]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [with no, definite_negated_existence]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [with no, definite_negated_existence]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [cannot be excluded, ambivalent_existence]
#
# <TagObject> [No definite, definite_negated_existence]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [No definite, definite_negated_existence]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [Increased, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [no appreciable change in, historical]
#
# <TagObject> [no appreciable change in, historical]
#
# <TagObject> [No change in, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [no appreciable change in, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [prior study, historical]
#
# <TagObject> [no significant change, historical]
#
# <TagObject> [no significant change, historical]
#
# <TagObject> [no significant change in, historical]
#
# <TagObject> [no significant change in, historical]
#
# <TagObject> [prior study, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [prior study, historical]
#
# <TagObject> [no significant change, historical]
#
# <TagObject> [no significant change in, historical]
#
# <TagObject> [no significant change in, historical]
#
# <TagObject> [no significant change in, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [no significant change in, historical]
#
# <TagObject> [no significant change in, historical]
#
# <TagObject> [no significant change in, historical]
#
# <TagObject> [no significant change in, historical]
#
# <TagObject> [no significant change in, historical]
#
# <TagObject> [no significant change in, historical]
#
# <TagObject> [no significant change in, historical]
#
# <TagObject> [no significant change in, historical]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [No other, probable_negated_existence]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [prior study, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [prior study, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [no signs, definite_negated_existence]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [prior study, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [decrease in, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [no significant, probable_negated_existence]
#
# <TagObject> [no significant change, historical]
#
# <TagObject> [no significant change, historical]
#
# <TagObject> [no significant change in, historical]
#
# <TagObject> [no significant change in, historical]
#
# <TagObject> [No significant, probable_negated_existence]
#
# <TagObject> [No significant change, historical]
#
# <TagObject> [No significant change, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [no significant change, historical]
#
# <TagObject> [no significant change in, historical]
#
# <TagObject> [no significant change in, historical]
#
# <TagObject> [no significant change in, historical]
#
# <TagObject> [No significant change, historical]
#
# <TagObject> [No significant change, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [no significant change in, historical]
#
# <TagObject> [no significant change in, historical]
#
# <TagObject> [no significant change in, historical]
#
# <TagObject> [no significant change in, historical]
#
# <TagObject> [no significant change in, historical]
#
# <TagObject> [no significant change in, historical]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [cannot be excluded, ambivalent_existence]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [No definite, definite_negated_existence]
#
# <TagObject> [cannot, ambivalent_existence]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [cannot, ambivalent_existence]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [likely representing, probable_existence]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [likely representing, probable_existence]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [prior study, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [prior study, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [prior study, historical]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [No focal opacities are seen to suggest, definite_negated_existence]
#
# <TagObject> [No focal opacities are seen to suggest, definite_negated_existence]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [No focal opacities are seen to suggest, definite_negated_existence]
#
# <TagObject> [No focal opacities are seen to suggest, definite_negated_existence]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [No focal opacities are seen to suggest, definite_negated_existence]
#
# <TagObject> [No focal opacities are seen to suggest, definite_negated_existence]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [likely represents, probable_existence]
#
# <TagObject> [likely represents, probable_existence]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [likely represents, probable_existence]
#
# <TagObject> [likely represents, probable_existence]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [likely represents, probable_existence]
#
# <TagObject> [likely represents, probable_existence]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [no change, historical]
#
# <TagObject> [no change in, historical]
#
# <TagObject> [no change in, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [no change in, historical]
#
# <TagObject> [no change in, historical]
#
# <TagObject> [no change in, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [no change in, historical]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [no change in, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [No definite evidence of, definite_negated_existence]
#
# <TagObject> [No definite evidence of, definite_negated_existence]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [increase, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [cannot be excluded, ambivalent_existence]
#
# <TagObject> [cannot be excluded, ambivalent_existence]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [cannot be excluded, ambivalent_existence]
#
# <TagObject> [cannot be excluded, ambivalent_existence]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [cannot be excluded, ambivalent_existence]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [cannot be excluded, ambivalent_existence]
#
# <TagObject> [cannot be excluded, ambivalent_existence]
#
# <TagObject> [cannot be excluded, ambivalent_existence]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [cannot be excluded, ambivalent_existence]
#
# <TagObject> [cannot be excluded, ambivalent_existence]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [prior study, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [cannot be excluded, ambivalent_existence]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [increase, historical]
#
# <TagObject> [decrease in, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [decrease in, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [no definite, definite_negated_existence]
#
# <TagObject> [no definite, definite_negated_existence]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [no definite, definite_negated_existence]
#
# <TagObject> [no definite, definite_negated_existence]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [no definite, definite_negated_existence]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [increased, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [No acute changes, historical]
#
# <TagObject> [No acute changes, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [No acute changes, historical]
#
# <TagObject> [No acute changes, historical]
#
# <TagObject> [No acute changes, historical]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [no significant, probable_negated_existence]
#
# <TagObject> [no significant interval change, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR, conj]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [not significantly changed, historical]
#
# <TagObject> [not significantly changed, historical]
#
# <TagObject> [prior study, historical]
#
# <TagObject> [not changed, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [not significantly changed, historical]
#
# <TagObject> [not significantly changed, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [not significantly changed, historical]
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [increase, historical]
#
# <TagObject> [increase, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]
#
# <TagObject> [increase, historical]
#
# <TagObject> [REASON FOR THIS EXAMINATION, indication]

# %%
for doc in docs:
    print(doc.ents)
    print(doc._.context_graph.modifiers)
    print(doc._.context_graph.edges)
    print()
# Out:
# (effusion, effusion)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [examination, indication], <TagObject> [appear, probable_existence], <TagObject> [unchanged, historical], <TagObject> [unchanged, historical], <TagObject> [unchanged, historical], <TagObject> [again, historical], <TagObject> [No, definite_negated_existence], <TagObject> [Improving, historical], <TagObject> [stable, historical], <TagObject> [unchanged, historical]]
# [(effusion, <TagObject> [unchanged, historical]), (effusion, <TagObject> [stable, historical])]
#
# (consolidation, effusion, pneumonia)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [consistent with, definite_existence], <TagObject> [unchanged, historical]]
# [(consolidation, <TagObject> [consistent with, definite_existence])]
#
# (pneumonia, pneumonia, Pneumonia, effusion, effusion, effusion)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [increased, historical], <TagObject> [increased, historical], <TagObject> [no, definite_negated_existence], <TagObject> [evidence, definite_existence], <TagObject> [stable, historical], <TagObject> [likely, probable_existence], <TagObject> [previously described, historical], <TagObject> [residual, historical], <TagObject> [persistent, historical], <TagObject> [Stable, historical], <TagObject> [without, definite_negated_existence], <TagObject> [without change, historical], <TagObject> [no, definite_negated_existence], <TagObject> [likely, probable_existence], <TagObject> [Improving, historical], <TagObject> [which, conj], <TagObject> [may reflect, probable_existence], <TagObject> [improving, historical], <TagObject> [not, definite_negated_existence], <TagObject> [excluded, definite_negated_existence], <TagObject> [excluded, definite_negated_existence], <TagObject> [cannot, ambivalent_existence], <TagObject> [not, definite_negated_existence], <TagObject> [study, indication]]
# [(pneumonia, <TagObject> [old, historical]), (pneumonia, <TagObject> [REASON FOR THIS EXAMINATION, indication]), (Pneumonia, <TagObject> [INDICATION, indication]), (effusion, <TagObject> [persistent, historical]), (effusion, <TagObject> [not, definite_negated_existence]), (effusion, <TagObject> [study, indication])]
#
# (effusions,)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [old, historical], <TagObject> [Evaluate for, indication], <TagObject> [not, definite_negated_existence], <TagObject> [likely, probable_existence], <TagObject> [no, definite_negated_existence], <TagObject> [clear, probable_negated_existence], <TagObject> [without, definite_negated_existence], <TagObject> [No, definite_negated_existence], <TagObject> [acute, acute]]
# [(effusions, <TagObject> [clear, probable_negated_existence]), (effusions, <TagObject> [without, definite_negated_existence])]
#
# (infiltrate, infiltrate)
# [<TagObject> [acute, acute], <TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [acute, acute], <TagObject> [INDICATION, indication], <TagObject> [old, historical], <TagObject> [Again, historical], <TagObject> [new, acute], <TagObject> [consistent with, definite_existence], <TagObject> [acute, acute], <TagObject> [stable, historical], <TagObject> [Acute, acute]]
# [(infiltrate, <TagObject> [acute, acute]), (infiltrate, <TagObject> [acute, acute])]
#
# (effusions, effusions)
# [<TagObject> [interval change, historical], <TagObject> [but, conj], <TagObject> [old, historical], <TagObject> [but, conj], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [interval change, historical], <TagObject> [but, conj], <TagObject> [INDICATION, indication], <TagObject> [unchanged, historical], <TagObject> [unchanged, historical], <TagObject> [but, conj], <TagObject> [no, definite_negated_existence], <TagObject> [no definite, definite_negated_existence], <TagObject> [definite, definite_existence], <TagObject> [evidence, definite_existence], <TagObject> [No, definite_negated_existence], <TagObject> [unchanged, historical], <TagObject> [No, definite_negated_existence], <TagObject> [No significant, probable_negated_existence], <TagObject> [No significant interval change, historical], <TagObject> [interval change, historical], <TagObject> [change in, historical]]
# [(effusions, <TagObject> [unchanged, historical]), (effusions, <TagObject> [interval change, historical]), (effusions, <TagObject> [change in, historical])]
#
# (effusions,)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [clear, probable_negated_existence], <TagObject> [no, definite_negated_existence], <TagObject> [appear, probable_existence], <TagObject> [without, definite_negated_existence], <TagObject> [evidence, definite_existence]]
# [(effusions, <TagObject> [no, definite_negated_existence])]
#
# (effusions, effusions, effusion)
# [<TagObject> [old, historical], <TagObject> [likely, probable_existence], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [REASON FOR, conj], <TagObject> [EXAMINATION, indication], <TagObject> [with no, definite_negated_existence], <TagObject> [no, definite_negated_existence], <TagObject> [previous, historical], <TagObject> [though, conj], <TagObject> [again, historical], <TagObject> [no, definite_negated_existence]]
# [(effusions, <TagObject> [old, historical]), (effusions, <TagObject> [likely, probable_existence]), (effusion, <TagObject> [no, definite_negated_existence])]
#
# (infiltrate, infiltrate, effusion, effusion, pneumonia, consolidation, effusion, effusion)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [not, definite_negated_existence], <TagObject> [still, conj], <TagObject> [diminished, historical], <TagObject> [but, conj], <TagObject> [stable, historical], <TagObject> [likely, probable_existence], <TagObject> [cannot, ambivalent_existence], <TagObject> [not, definite_negated_existence], <TagObject> [excluded, definite_negated_existence], <TagObject> [excluded, definite_negated_existence], <TagObject> [likely, probable_existence], <TagObject> [although, conj], <TagObject> [cannot, ambivalent_existence], <TagObject> [cannot be excluded, ambivalent_existence], <TagObject> [not, definite_negated_existence], <TagObject> [excluded, definite_negated_existence], <TagObject> [excluded, definite_negated_existence], <TagObject> [No, definite_negated_existence], <TagObject> [No definite, definite_negated_existence], <TagObject> [definite, definite_existence], <TagObject> [examination, indication], <TagObject> [No, definite_negated_existence], <TagObject> [definite, definite_existence], <TagObject> [although, conj], <TagObject> [which, conj], <TagObject> [but, conj], <TagObject> [stable, historical]]
# [(infiltrate, <TagObject> [old, historical]), (infiltrate, <TagObject> [REASON FOR THIS EXAMINATION, indication]), (effusion, <TagObject> [likely, probable_existence]), (effusion, <TagObject> [not, definite_negated_existence]), (effusion, <TagObject> [excluded, definite_negated_existence]), (effusion, <TagObject> [excluded, definite_negated_existence]), (pneumonia, <TagObject> [cannot be excluded, ambivalent_existence]), (pneumonia, <TagObject> [not, definite_negated_existence]), (consolidation, <TagObject> [definite, definite_existence])]
#
# (consolidation, effusion, pneumonia)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [increased, historical], <TagObject> [increased, historical], <TagObject> [stable, historical], <TagObject> [concerning for, probable_existence]]
# [(consolidation, <TagObject> [increased, historical]), (consolidation, <TagObject> [increased, historical]), (effusion, <TagObject> [increased, historical]), (effusion, <TagObject> [increased, historical]), (pneumonia, <TagObject> [stable, historical]), (pneumonia, <TagObject> [concerning for, probable_existence])]
#
# (pneumonia, pneumonia, effusion, consolidation)
# [<TagObject> [interval change, historical], <TagObject> [old, historical], <TagObject> [interval change, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [interval change, historical], <TagObject> [INDICATION, indication], <TagObject> [No, definite_negated_existence]]
# [(pneumonia, <TagObject> [old, historical]), (pneumonia, <TagObject> [INDICATION, indication])]
#
# (effusion, consolidation)
# [<TagObject> [new, acute], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [new, acute], <TagObject> [No, definite_negated_existence], <TagObject> [equivocal, probable_existence], <TagObject> [equivocal, ambivalent_existence], <TagObject> [not, definite_negated_existence], <TagObject> [likely, probable_existence], <TagObject> [secondary to, conj]]
# [(effusion, <TagObject> [equivocal, probable_existence]), (effusion, <TagObject> [equivocal, ambivalent_existence])]
#
# (infiltrate, infiltrate, bronchopneumonia)
# [<TagObject> [old, historical], <TagObject> [signs of, probable_existence], <TagObject> [exam, indication], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [previous, historical], <TagObject> [prior, historical], <TagObject> [increased, historical], <TagObject> [increased, historical], <TagObject> [involving, conj], <TagObject> [history of, historical], <TagObject> [worrisome, probable_existence], <TagObject> [chronic, historical], <TagObject> [evaluation, indication], <TagObject> [could represent, probable_existence], <TagObject> [no, definite_negated_existence], <TagObject> [evidence, definite_existence], <TagObject> [No, definite_negated_existence], <TagObject> [Increased, historical], <TagObject> [Increased, historical], <TagObject> [involving, conj]]
# [(bronchopneumonia, <TagObject> [could represent, probable_existence])]
#
# (effusions, pneumonia, effusions, pneumonia, effusion)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [no, definite_negated_existence], <TagObject> [no appreciable change, historical], <TagObject> [no appreciable change in, historical], <TagObject> [change in, historical], <TagObject> [no, definite_negated_existence], <TagObject> [unchanged, historical], <TagObject> [No, definite_negated_existence], <TagObject> [No change, historical], <TagObject> [No change in, historical], <TagObject> [change in, historical]]
# [(effusions, <TagObject> [old, historical]), (pneumonia, <TagObject> [old, historical])]
#
# (infiltrates, infiltrates, consolidation, effusion)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [old, historical], <TagObject> [evaluate for, indication], <TagObject> [No, definite_negated_existence], <TagObject> [prior, historical], <TagObject> [which, conj], <TagObject> [could be, probable_existence], <TagObject> [which, conj], <TagObject> [not, definite_negated_existence], <TagObject> [but, conj]]
# [(infiltrates, <TagObject> [old, historical]), (infiltrates, <TagObject> [REASON FOR THIS EXAMINATION, indication]), (infiltrates, <TagObject> [INDICATION, indication]), (infiltrates, <TagObject> [old, historical]), (consolidation, <TagObject> [could be, probable_existence])]
#
# (pneumonia, infiltrate)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [old, historical], <TagObject> [prior, historical], <TagObject> [prior study, historical], <TagObject> [study, indication], <TagObject> [again, historical], <TagObject> [unchanged, historical], <TagObject> [no, definite_negated_existence], <TagObject> [no significant, probable_negated_existence], <TagObject> [no significant change, historical], <TagObject> [no significant change, historical], <TagObject> [no significant change in, historical], <TagObject> [change in, historical], <TagObject> [no, definite_negated_existence], <TagObject> [change in, historical], <TagObject> [excluded, definite_negated_existence], <TagObject> [excluded, definite_negated_existence], <TagObject> [cannot, ambivalent_existence], <TagObject> [not, definite_negated_existence], <TagObject> [no, definite_negated_existence], <TagObject> [prior, historical], <TagObject> [prior study, historical], <TagObject> [study, indication]]
# [(pneumonia, <TagObject> [old, historical]), (infiltrate, <TagObject> [change in, historical])]
#
# (infiltrate, infiltrate)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [stable, historical], <TagObject> [but, conj], <TagObject> [unchanged, historical], <TagObject> [stable, historical], <TagObject> [Stable, historical], <TagObject> [without, definite_negated_existence], <TagObject> [acute, acute]]
# [(infiltrate, <TagObject> [old, historical]), (infiltrate, <TagObject> [REASON FOR THIS EXAMINATION, indication]), (infiltrate, <TagObject> [INDICATION, indication]), (infiltrate, <TagObject> [INDICATION, indication])]
#
# (infiltrates, infiltrates, pneumonia)
# [<TagObject> [evaluate for, indication], <TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [evaluate for, indication], <TagObject> [CLINICAL HISTORY, historical], <TagObject> [old, historical], <TagObject> [Known, historical], <TagObject> [not, definite_negated_existence], <TagObject> [clear, probable_negated_existence], <TagObject> [No, definite_negated_existence], <TagObject> [evidence, definite_existence]]
# [(infiltrates, <TagObject> [evaluate for, indication]), (infiltrates, <TagObject> [evaluate for, indication]), (pneumonia, <TagObject> [evidence, definite_existence])]
#
# (effusion,)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [no, definite_negated_existence]]
# [(effusion, <TagObject> [no, definite_negated_existence])]
#
# (Consolidation, effusions, pneumonia)
# [<TagObject> [old, historical], <TagObject> [acute, acute], <TagObject> [likely, probable_existence], <TagObject> [old, historical], <TagObject> [acute, acute], <TagObject> [likely, probable_existence], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [old, historical], <TagObject> [acute, acute], <TagObject> [likely, probable_existence], <TagObject> [INDICATION, indication], <TagObject> [no, definite_negated_existence], <TagObject> [No, definite_negated_existence], <TagObject> [No other, probable_negated_existence], <TagObject> [likely, probable_existence]]
# [(effusions, <TagObject> [no, definite_negated_existence]), (pneumonia, <TagObject> [likely, probable_existence])]
#
# (effusions, consolidation, consolidation, effusions, consolidation)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [old, historical], <TagObject> [prior, historical], <TagObject> [prior study, historical], <TagObject> [study, indication], <TagObject> [consistent with, definite_existence], <TagObject> [consistent with, definite_existence], <TagObject> [possibly, probable_existence], <TagObject> [secondary to, conj], <TagObject> [Persistent, historical]]
# [(effusions, <TagObject> [consistent with, definite_existence]), (effusions, <TagObject> [Persistent, historical])]
#
# (infiltrates,)
# [<TagObject> [old, historical], <TagObject> [likely, probable_existence], <TagObject> [but, conj], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [likely, probable_existence], <TagObject> [but, conj], <TagObject> [Evaluate for, indication], <TagObject> [appears, probable_existence], <TagObject> [however, conj], <TagObject> [no, definite_negated_existence], <TagObject> [evidence, definite_existence], <TagObject> [no, definite_negated_existence], <TagObject> [no signs, definite_negated_existence], <TagObject> [signs of, probable_existence], <TagObject> [acute, acute], <TagObject> [examination, indication], <TagObject> [free, definite_negated_existence], <TagObject> [no, definite_negated_existence], <TagObject> [evidence, definite_existence], <TagObject> [but, conj], <TagObject> [no, definite_negated_existence], <TagObject> [evidence, definite_existence], <TagObject> [acute, acute]]
# [(infiltrates, <TagObject> [no, definite_negated_existence]), (infiltrates, <TagObject> [no signs, definite_negated_existence]), (infiltrates, <TagObject> [acute, acute]), (infiltrates, <TagObject> [examination, indication])]
#
# (consolidation, effusion, consolidation, effusion, pneumonia)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [old, historical], <TagObject> [no, definite_negated_existence], <TagObject> [previous, historical], <TagObject> [associated with, probable_existence], <TagObject> [associated with, probable_existence], <TagObject> [which, conj], <TagObject> [prior, historical], <TagObject> [which, conj], <TagObject> [prior, historical], <TagObject> [prior study, historical], <TagObject> [study, indication]]
# [(effusion, <TagObject> [associated with, probable_existence])]
#
# (effusion,)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [old, historical], <TagObject> [Again, historical], <TagObject> [unchanged, historical], <TagObject> [clear, probable_negated_existence], <TagObject> [no, definite_negated_existence], <TagObject> [evidence, definite_existence], <TagObject> [No, definite_negated_existence]]
# [(effusion, <TagObject> [evidence, definite_existence])]
#
# ()
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [old, historical], <TagObject> [Evaluate for, indication], <TagObject> [No, definite_negated_existence], <TagObject> [appears to be, definite_existence], <TagObject> [appears, probable_existence], <TagObject> [consistent with, definite_existence], <TagObject> [known, historical], <TagObject> [evaluation, indication], <TagObject> [consistent with, definite_existence], <TagObject> [no, definite_negated_existence], <TagObject> [evidence, definite_existence]]
# []
#
# (pneumonia, pneumonia)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [examination, indication], <TagObject> [unchanged, historical], <TagObject> [not, definite_negated_existence], <TagObject> [If, hypothetical], <TagObject> [stable, historical], <TagObject> [decrease in, historical], <TagObject> [decrease in, historical], <TagObject> [decrease, historical]]
# [(pneumonia, <TagObject> [old, historical])]
#
# ()
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [which, conj], <TagObject> [may represent, probable_existence]]
# []
#
# (pneumonia, pneumonia, pneumonia, effusions, Effusions, consolidation, effusion, pneumonia)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [although, conj], <TagObject> [suggesting, probable_existence], <TagObject> [cannot, ambivalent_existence], <TagObject> [cannot exclude, ambivalent_existence], <TagObject> [not, definite_negated_existence]]
# [(pneumonia, <TagObject> [old, historical]), (pneumonia, <TagObject> [REASON FOR THIS EXAMINATION, indication]), (Effusions, <TagObject> [not, definite_negated_existence]), (consolidation, <TagObject> [cannot, ambivalent_existence]), (consolidation, <TagObject> [cannot exclude, ambivalent_existence]), (consolidation, <TagObject> [not, definite_negated_existence])]
#
# (effusions, consolidation, infiltrate)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [no, definite_negated_existence], <TagObject> [no significant, probable_negated_existence], <TagObject> [no significant change, historical], <TagObject> [no significant change, historical], <TagObject> [no significant change in, historical], <TagObject> [change in, historical], <TagObject> [probable, probable_existence], <TagObject> [though, conj], <TagObject> [not, definite_negated_existence], <TagObject> [No, definite_negated_existence], <TagObject> [No significant, probable_negated_existence], <TagObject> [No significant change, historical], <TagObject> [No significant change, historical], <TagObject> [involving, conj]]
# [(effusions, <TagObject> [probable, probable_existence]), (effusions, <TagObject> [not, definite_negated_existence])]
#
# (infiltrates, infiltrate, consolidation)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [is present, definite_existence], <TagObject> [which, conj], <TagObject> [is present, definite_existence], <TagObject> [which, conj], <TagObject> [are present, definite_existence], <TagObject> [likely, probable_existence], <TagObject> [consistent with, definite_existence], <TagObject> [No, definite_negated_existence], <TagObject> [are present, definite_existence], <TagObject> [no, definite_negated_existence], <TagObject> [likely, probable_existence], <TagObject> [consistent with, definite_existence], <TagObject> [No, definite_negated_existence], <TagObject> [acute, acute]]
# [(infiltrates, <TagObject> [No, definite_negated_existence]), (infiltrates, <TagObject> [are present, definite_existence]), (infiltrate, <TagObject> [No, definite_negated_existence]), (infiltrate, <TagObject> [acute, acute]), (consolidation, <TagObject> [No, definite_negated_existence]), (consolidation, <TagObject> [acute, acute])]
#
# (pneumonia, pneumonias, pneumonia, effusions, effusions)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [prior, historical], <TagObject> [examination, indication], <TagObject> [unchanged, historical], <TagObject> [appears, probable_existence], <TagObject> [appear, probable_existence], <TagObject> [again, historical], <TagObject> [compatible with, definite_existence], <TagObject> [cannot, ambivalent_existence], <TagObject> [cannot be excluded, ambivalent_existence], <TagObject> [not, definite_negated_existence], <TagObject> [excluded, definite_negated_existence], <TagObject> [excluded, definite_negated_existence]]
# [(pneumonia, <TagObject> [old, historical]), (pneumonias, <TagObject> [old, historical]), (pneumonia, <TagObject> [INDICATION, indication])]
#
# (effusions, effusion)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [previous, historical], <TagObject> [which, conj], <TagObject> [represents, definite_existence], <TagObject> [stable, historical]]
# [(effusions, <TagObject> [represents, definite_existence]), (effusion, <TagObject> [represents, definite_existence])]
#
# (consolidation, consolidation)
# [<TagObject> [free, definite_negated_existence], <TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [free, definite_negated_existence], <TagObject> [INDICATION, indication], <TagObject> [rule out, indication], <TagObject> [free, definite_negated_existence], <TagObject> [No, definite_negated_existence], <TagObject> [No definite, definite_negated_existence], <TagObject> [definite, definite_existence], <TagObject> [free, definite_negated_existence], <TagObject> [however, conj], <TagObject> [free, definite_negated_existence], <TagObject> [cannot, ambivalent_existence], <TagObject> [not, definite_negated_existence], <TagObject> [excluded, definite_negated_existence], <TagObject> [excluded, definite_negated_existence], <TagObject> [study, indication], <TagObject> [incompletely evaluated, ambivalent_existence], <TagObject> [exam, indication], <TagObject> [to exclude, probable_negated_existence], <TagObject> [free, definite_negated_existence]]
# []
#
# (effusions, effusions, pneumonia, pneumonia, effusion, consolidation, effusion, Consolidation, effusion)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [evidence, definite_existence], <TagObject> [cannot, ambivalent_existence], <TagObject> [not, definite_negated_existence], <TagObject> [be ruled out, indication], <TagObject> [ruled out, definite_negated_existence], <TagObject> [No, definite_negated_existence], <TagObject> [could be, probable_existence], <TagObject> [Possible, probable_existence], <TagObject> [No, definite_negated_existence], <TagObject> [evidence, definite_existence]]
# [(effusions, <TagObject> [old, historical]), (effusions, <TagObject> [INDICATION, indication]), (consolidation, <TagObject> [evidence, definite_existence]), (effusion, <TagObject> [not, definite_negated_existence]), (effusion, <TagObject> [be ruled out, indication]), (effusion, <TagObject> [ruled out, definite_negated_existence]), (effusion, <TagObject> [Possible, probable_existence])]
#
# (consolidation, effusion, pneumonia)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [no, definite_negated_existence], <TagObject> [no, definite_negated_existence], <TagObject> [likely, probable_existence], <TagObject> [likely, probable_existence], <TagObject> [likely representing, probable_existence], <TagObject> [prior, historical], <TagObject> [exams, indication], <TagObject> [suggested, probable_existence], <TagObject> [absence of, definite_negated_existence], <TagObject> [prior, historical], <TagObject> [No, definite_negated_existence]]
# [(consolidation, <TagObject> [no, definite_negated_existence]), (effusion, <TagObject> [no, definite_negated_existence]), (pneumonia, <TagObject> [No, definite_negated_existence])]
#
# (infiltrate, infiltrate, infiltrate, effusions)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [old, historical], <TagObject> [prior, historical], <TagObject> [probable, probable_existence], <TagObject> [unchanged, historical], <TagObject> [no, definite_negated_existence], <TagObject> [no, definite_negated_existence], <TagObject> [evidence, definite_existence], <TagObject> [stable, historical], <TagObject> [exam, indication]]
# [(infiltrate, <TagObject> [old, historical]), (infiltrate, <TagObject> [REASON FOR THIS EXAMINATION, indication]), (infiltrate, <TagObject> [old, historical]), (infiltrate, <TagObject> [old, historical]), (effusions, <TagObject> [probable, probable_existence]), (effusions, <TagObject> [unchanged, historical])]
#
# (effusion, effusion)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [prior, historical], <TagObject> [no, definite_negated_existence], <TagObject> [evidence, definite_existence], <TagObject> [previous, historical], <TagObject> [stable, historical], <TagObject> [prior, historical], <TagObject> [prior study, historical], <TagObject> [study, indication], <TagObject> [persistent, historical], <TagObject> [probable, probable_existence], <TagObject> [No, definite_negated_existence], <TagObject> [Persistent, historical], <TagObject> [probable, probable_existence]]
# [(effusion, <TagObject> [probable, probable_existence]), (effusion, <TagObject> [probable, probable_existence])]
#
# ()
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [No, definite_negated_existence], <TagObject> [is present, definite_existence]]
# []
#
# (effusion,)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [old, historical], <TagObject> [previous, historical], <TagObject> [study, indication], <TagObject> [No, definite_negated_existence]]
# []
#
# (pneumonia, pneumonia, effusions, pneumonia)
# [<TagObject> [old, historical], <TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [old, historical], <TagObject> [INDICATION, indication], <TagObject> [prior, historical], <TagObject> [examination, indication], <TagObject> [known, historical], <TagObject> [history of, historical], <TagObject> [consistent with, definite_existence], <TagObject> [No, definite_negated_existence], <TagObject> [No focal opacities are seen to suggest, definite_negated_existence], <TagObject> [suggest, probable_existence], <TagObject> [No, definite_negated_existence], <TagObject> [No, definite_negated_existence], <TagObject> [No, definite_negated_existence], <TagObject> [evidence, definite_existence]]
# [(pneumonia, <TagObject> [No, definite_negated_existence]), (pneumonia, <TagObject> [No focal opacities are seen to suggest, definite_negated_existence]), (pneumonia, <TagObject> [suggest, probable_existence]), (effusions, <TagObject> [No, definite_negated_existence]), (pneumonia, <TagObject> [evidence, definite_existence])]
#
# (effusion,)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [unchanged, historical], <TagObject> [stable, historical], <TagObject> [prior, historical], <TagObject> [unchanged, historical], <TagObject> [No, definite_negated_existence], <TagObject> [interval change, historical]]
# [(effusion, <TagObject> [unchanged, historical])]
#
# (infiltrate, infiltrate, effusions, pneumonia, effusions)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [No, definite_negated_existence], <TagObject> [prior, historical], <TagObject> [no, definite_negated_existence], <TagObject> [evidence, definite_existence], <TagObject> [consistent with, definite_existence], <TagObject> [not, definite_negated_existence], <TagObject> [which, conj], <TagObject> [likely, probable_existence], <TagObject> [likely represents, probable_existence], <TagObject> [represents, definite_existence], <TagObject> [appear, probable_existence], <TagObject> [consistent with, definite_existence], <TagObject> [study, indication], <TagObject> [which, conj], <TagObject> [No, definite_negated_existence], <TagObject> [evidence, definite_existence]]
# [(infiltrate, <TagObject> [old, historical]), (pneumonia, <TagObject> [consistent with, definite_existence])]
#
# (pneumonia, pneumonia, pneumonia, infiltrates, effusions, pneumonia)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [old, historical], <TagObject> [prior, historical], <TagObject> [no, definite_negated_existence], <TagObject> [no change, historical], <TagObject> [no change in, historical], <TagObject> [change in, historical], <TagObject> [no, definite_negated_existence], <TagObject> [No, definite_negated_existence]]
# [(pneumonia, <TagObject> [old, historical]), (pneumonia, <TagObject> [REASON FOR THIS EXAMINATION, indication]), (pneumonia, <TagObject> [INDICATION, indication]), (pneumonia, <TagObject> [old, historical]), (pneumonia, <TagObject> [INDICATION, indication]), (pneumonia, <TagObject> [old, historical]), (pneumonia, <TagObject> [prior, historical]), (infiltrates, <TagObject> [no, definite_negated_existence]), (effusions, <TagObject> [no, definite_negated_existence]), (pneumonia, <TagObject> [No, definite_negated_existence])]
#
# ()
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [no, definite_negated_existence], <TagObject> [unchanged, historical], <TagObject> [No, definite_negated_existence], <TagObject> [no, definite_negated_existence], <TagObject> [no change, historical], <TagObject> [no change in, historical], <TagObject> [change in, historical]]
# []
#
# (consolidation, consolidation)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [old, historical], <TagObject> [consistent with, definite_existence], <TagObject> [new, acute], <TagObject> [no, definite_negated_existence], <TagObject> [new, acute], <TagObject> [study, indication]]
# [(consolidation, <TagObject> [old, historical]), (consolidation, <TagObject> [REASON FOR THIS EXAMINATION, indication]), (consolidation, <TagObject> [old, historical]), (consolidation, <TagObject> [old, historical])]
#
# (effusion, effusion, effusion)
# [<TagObject> [still, conj], <TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [still, conj], <TagObject> [still, conj], <TagObject> [previous, historical], <TagObject> [appear, probable_existence], <TagObject> [but, conj], <TagObject> [not, definite_negated_existence], <TagObject> [appears, probable_existence], <TagObject> [not, definite_negated_existence], <TagObject> [No, definite_negated_existence], <TagObject> [No definite, definite_negated_existence], <TagObject> [No definite evidence of, definite_negated_existence], <TagObject> [definite, definite_existence], <TagObject> [evidence, definite_existence]]
# []
#
# (consolidation, effusions, pneumonia)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [old, historical], <TagObject> [possibly, probable_existence], <TagObject> [no, definite_negated_existence], <TagObject> [new, acute], <TagObject> [No, definite_negated_existence], <TagObject> [suggesting, probable_existence]]
# [(consolidation, <TagObject> [new, acute]), (effusions, <TagObject> [No, definite_negated_existence]), (pneumonia, <TagObject> [suggesting, probable_existence])]
#
# (pneumonia, effusion)
# [<TagObject> [old, historical], <TagObject> [increase, historical], <TagObject> [increase, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [increasing, historical], <TagObject> [increasing, historical], <TagObject> [cannot, ambivalent_existence], <TagObject> [not, definite_negated_existence], <TagObject> [unchanged, historical], <TagObject> [unchanged, historical], <TagObject> [could represent, probable_existence], <TagObject> [no, definite_negated_existence], <TagObject> [unchanged, historical]]
# [(pneumonia, <TagObject> [could represent, probable_existence]), (effusion, <TagObject> [no, definite_negated_existence])]
#
# (effusion,)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [study, indication], <TagObject> [questionable, probable_negated_existence], <TagObject> [incompletely evaluated, ambivalent_existence]]
# []
#
# (pneumonia, effusion)
# [<TagObject> [old, historical], <TagObject> [likely, probable_existence], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [Evaluate for, indication], <TagObject> [no, definite_negated_existence], <TagObject> [cannot, ambivalent_existence], <TagObject> [cannot be excluded, ambivalent_existence], <TagObject> [not, definite_negated_existence], <TagObject> [excluded, definite_negated_existence], <TagObject> [excluded, definite_negated_existence], <TagObject> [suggests, probable_existence], <TagObject> [evidence, definite_existence], <TagObject> [prior, historical], <TagObject> [unchanged, historical], <TagObject> [No, definite_negated_existence], <TagObject> [exam, indication], <TagObject> [unchanged, historical], <TagObject> [prior, historical]]
# [(pneumonia, <TagObject> [likely, probable_existence]), (effusion, <TagObject> [cannot be excluded, ambivalent_existence]), (effusion, <TagObject> [not, definite_negated_existence])]
#
# (effusion,)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [old, historical]]
# []
#
# (effusions, infiltrate, pneumonias)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [No, definite_negated_existence], <TagObject> [probable, probable_existence], <TagObject> [cannot, ambivalent_existence], <TagObject> [cannot be excluded, ambivalent_existence], <TagObject> [not, definite_negated_existence], <TagObject> [excluded, definite_negated_existence], <TagObject> [excluded, definite_negated_existence], <TagObject> [No, definite_negated_existence], <TagObject> [consistent with, definite_existence], <TagObject> [although, conj], <TagObject> [cannot, ambivalent_existence], <TagObject> [cannot be excluded, ambivalent_existence], <TagObject> [not, definite_negated_existence], <TagObject> [excluded, definite_negated_existence], <TagObject> [excluded, definite_negated_existence]]
# [(effusions, <TagObject> [probable, probable_existence]), (infiltrate, <TagObject> [cannot be excluded, ambivalent_existence]), (infiltrate, <TagObject> [not, definite_negated_existence]), (pneumonias, <TagObject> [cannot be excluded, ambivalent_existence]), (pneumonias, <TagObject> [not, definite_negated_existence])]
#
# (pneumonia, pneumonia, pneumonia, pneumonia, effusion, consolidation, pneumonia, pneumonia)
# [<TagObject> [evaluate for, indication], <TagObject> [old, historical], <TagObject> [history of, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [evaluate for, indication], <TagObject> [INDICATION, indication], <TagObject> [History of, historical], <TagObject> [No, definite_negated_existence], <TagObject> [prior, historical], <TagObject> [which, conj], <TagObject> [appear, probable_existence], <TagObject> [not, definite_negated_existence], <TagObject> [No, definite_negated_existence], <TagObject> [evidence, definite_existence], <TagObject> [no, definite_negated_existence], <TagObject> [evidence, definite_existence], <TagObject> [consistent with, definite_existence], <TagObject> [consistent with, definite_existence]]
# [(pneumonia, <TagObject> [evaluate for, indication]), (pneumonia, <TagObject> [old, historical]), (pneumonia, <TagObject> [REASON FOR THIS EXAMINATION, indication]), (pneumonia, <TagObject> [INDICATION, indication]), (pneumonia, <TagObject> [old, historical]), (pneumonia, <TagObject> [history of, historical]), (pneumonia, <TagObject> [REASON FOR THIS EXAMINATION, indication]), (pneumonia, <TagObject> [INDICATION, indication]), (pneumonia, <TagObject> [evaluate for, indication]), (pneumonia, <TagObject> [INDICATION, indication]), (pneumonia, <TagObject> [INDICATION, indication]), (pneumonia, <TagObject> [History of, historical]), (effusion, <TagObject> [evidence, definite_existence]), (consolidation, <TagObject> [no, definite_negated_existence])]
#
# ()
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [Rule out, indication], <TagObject> [which, conj], <TagObject> [unchanged, historical], <TagObject> [previous, historical], <TagObject> [study, indication], <TagObject> [clear, probable_negated_existence], <TagObject> [however, conj], <TagObject> [not, definite_negated_existence], <TagObject> [stable, historical], <TagObject> [no, definite_negated_existence], <TagObject> [evidence, definite_existence]]
# []
#
# ()
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [REASON FOR, conj], <TagObject> [EXAMINATION, indication], <TagObject> [known, historical], <TagObject> [previous, historical], <TagObject> [unchanged, historical], <TagObject> [Resolution of, historical]]
# []
#
# (Pneumonia, Pneumonia, pneumonia, infiltrate, pneumonia, pneumonia)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [evidence, definite_existence], <TagObject> [evidence, definite_existence], <TagObject> [could be, probable_existence], <TagObject> [versus, ambivalent_existence], <TagObject> [examination, indication], <TagObject> [Possible, probable_existence], <TagObject> [versus, ambivalent_existence]]
# [(infiltrate, <TagObject> [evidence, definite_existence]), (pneumonia, <TagObject> [could be, probable_existence]), (pneumonia, <TagObject> [versus, ambivalent_existence]), (pneumonia, <TagObject> [versus, ambivalent_existence])]
#
# (effusions, effusions, effusions)
# [<TagObject> [old, historical], <TagObject> [probable, probable_existence], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [old, historical], <TagObject> [probable, probable_existence], <TagObject> [increased, historical], <TagObject> [increased, historical], <TagObject> [clear, probable_negated_existence], <TagObject> [no, definite_negated_existence], <TagObject> [possibly, probable_existence], <TagObject> [evaluation, indication]]
# [(effusions, <TagObject> [no, definite_negated_existence])]
#
# (pneumonia, pneumonia, pneumonia, pneumonia, consolidation, effusions, pneumonia)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [appear, probable_existence], <TagObject> [unchanged, historical], <TagObject> [unchanged, historical], <TagObject> [prior, historical], <TagObject> [prior study, historical], <TagObject> [study, indication], <TagObject> [increased, historical], <TagObject> [increased, historical], <TagObject> [consistent with, definite_existence], <TagObject> [again, historical], <TagObject> [no, definite_negated_existence], <TagObject> [again, historical], <TagObject> [previous, historical], <TagObject> [study, indication]]
# [(pneumonia, <TagObject> [old, historical]), (pneumonia, <TagObject> [REASON FOR THIS EXAMINATION, indication]), (pneumonia, <TagObject> [INDICATION, indication]), (pneumonia, <TagObject> [old, historical]), (pneumonia, <TagObject> [REASON FOR THIS EXAMINATION, indication]), (pneumonia, <TagObject> [INDICATION, indication]), (pneumonia, <TagObject> [INDICATION, indication]), (pneumonia, <TagObject> [INDICATION, indication]), (consolidation, <TagObject> [prior, historical]), (consolidation, <TagObject> [prior study, historical]), (consolidation, <TagObject> [increased, historical]), (consolidation, <TagObject> [increased, historical]), (pneumonia, <TagObject> [previous, historical]), (pneumonia, <TagObject> [study, indication])]
#
# (infiltrate, infiltrate, infiltrate, effusion, Pneumonia, effusion)
# [<TagObject> [evaluate for, indication], <TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [evaluate for, indication], <TagObject> [INDICATION, indication], <TagObject> [History of, historical], <TagObject> [evaluate for, indication], <TagObject> [STUDY, indication], <TagObject> [no, definite_negated_existence], <TagObject> [increasing, historical], <TagObject> [increasing, historical], <TagObject> [cannot, ambivalent_existence], <TagObject> [cannot be excluded, ambivalent_existence], <TagObject> [not, definite_negated_existence], <TagObject> [excluded, definite_negated_existence], <TagObject> [excluded, definite_negated_existence], <TagObject> [without, definite_negated_existence], <TagObject> [Increasing, historical], <TagObject> [Increasing, historical]]
# [(infiltrate, <TagObject> [evaluate for, indication]), (infiltrate, <TagObject> [old, historical]), (infiltrate, <TagObject> [REASON FOR THIS EXAMINATION, indication]), (infiltrate, <TagObject> [INDICATION, indication]), (infiltrate, <TagObject> [evaluate for, indication]), (infiltrate, <TagObject> [INDICATION, indication]), (infiltrate, <TagObject> [evaluate for, indication]), (effusion, <TagObject> [increasing, historical]), (effusion, <TagObject> [increasing, historical]), (Pneumonia, <TagObject> [cannot be excluded, ambivalent_existence]), (Pneumonia, <TagObject> [not, definite_negated_existence]), (effusion, <TagObject> [Increasing, historical]), (effusion, <TagObject> [Increasing, historical])]
#
# (effusion, effusion)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [History of, historical], <TagObject> [evaluate for, indication], <TagObject> [Again, historical], <TagObject> [unchanged, historical], <TagObject> [No, definite_negated_existence], <TagObject> [new, acute], <TagObject> [examination, indication], <TagObject> [consistent with, definite_existence], <TagObject> [No, definite_negated_existence], <TagObject> [previous, historical], <TagObject> [examination, indication], <TagObject> [New, acute], <TagObject> [No, definite_negated_existence]]
# [(effusion, <TagObject> [new, acute]), (effusion, <TagObject> [examination, indication]), (effusion, <TagObject> [New, acute])]
#
# (effusion, effusion, effusion)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [old, historical], <TagObject> [increase, historical], <TagObject> [increase, historical], <TagObject> [concerning for, probable_existence], <TagObject> [probable, probable_existence], <TagObject> [decrease in, historical], <TagObject> [decrease in, historical], <TagObject> [decrease, historical], <TagObject> [which, conj], <TagObject> [persistent, historical], <TagObject> [study, indication]]
# [(effusion, <TagObject> [increase, historical]), (effusion, <TagObject> [increase, historical]), (effusion, <TagObject> [concerning for, probable_existence]), (effusion, <TagObject> [decrease in, historical]), (effusion, <TagObject> [decrease in, historical]), (effusion, <TagObject> [decrease, historical]), (effusion, <TagObject> [persistent, historical])]
#
# (infiltrate, infiltrate, consolidation, consolidation, infiltrate, infiltrate, effusion, infiltrate)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [Evidence, definite_existence], <TagObject> [Evidence, definite_existence], <TagObject> [Possible, probable_existence], <TagObject> [but, conj], <TagObject> [INDICATION, indication], <TagObject> [evaluate for, indication], <TagObject> [exam, indication], <TagObject> [unchanged, historical], <TagObject> [again, historical], <TagObject> [consistent with, definite_existence], <TagObject> [increased, historical], <TagObject> [increased, historical], <TagObject> [not, definite_negated_existence], <TagObject> [clear, probable_negated_existence], <TagObject> [if, hypothetical], <TagObject> [no, definite_negated_existence], <TagObject> [no definite, definite_negated_existence], <TagObject> [definite, definite_existence], <TagObject> [no, definite_negated_existence], <TagObject> [unchanged, historical], <TagObject> [Possible, probable_existence]]
# [(infiltrate, <TagObject> [old, historical]), (infiltrate, <TagObject> [REASON FOR THIS EXAMINATION, indication]), (consolidation, <TagObject> [Possible, probable_existence]), (infiltrate, <TagObject> [INDICATION, indication]), (infiltrate, <TagObject> [evaluate for, indication]), (infiltrate, <TagObject> [clear, probable_negated_existence]), (infiltrate, <TagObject> [if, hypothetical]), (effusion, <TagObject> [definite, definite_existence]), (infiltrate, <TagObject> [Possible, probable_existence])]
#
# (pneumonia, pneumonia, pneumonia, pneumonia, pneumonia)
# [<TagObject> [evaluate for, indication], <TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [evaluate for, indication], <TagObject> [CLINICAL HISTORY, historical], <TagObject> [evaluate for, indication], <TagObject> [is present, definite_existence], <TagObject> [clear, probable_negated_existence], <TagObject> [no, definite_negated_existence], <TagObject> [evidence, definite_existence], <TagObject> [No, definite_negated_existence]]
# [(pneumonia, <TagObject> [evaluate for, indication]), (pneumonia, <TagObject> [old, historical]), (pneumonia, <TagObject> [REASON FOR THIS EXAMINATION, indication]), (pneumonia, <TagObject> [evaluate for, indication]), (pneumonia, <TagObject> [evaluate for, indication]), (pneumonia, <TagObject> [evidence, definite_existence]), (pneumonia, <TagObject> [No, definite_negated_existence])]
#
# (effusion, effusion)
# [<TagObject> [old, historical], <TagObject> [increased, historical], <TagObject> [increased, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [old, historical], <TagObject> [previous, historical], <TagObject> [study, indication], <TagObject> [which, conj], <TagObject> [again, historical], <TagObject> [increased, historical], <TagObject> [increased, historical], <TagObject> [increased, historical], <TagObject> [increased, historical], <TagObject> [increased, historical], <TagObject> [increased, historical], <TagObject> [No, definite_negated_existence], <TagObject> [increased, historical], <TagObject> [increased, historical]]
# [(effusion, <TagObject> [increased, historical]), (effusion, <TagObject> [increased, historical]), (effusion, <TagObject> [increased, historical]), (effusion, <TagObject> [increased, historical])]
#
# (infiltrate, pneumonia)
# [<TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [prior, historical], <TagObject> [stable, historical], <TagObject> [No, definite_negated_existence], <TagObject> [No acute changes, historical], <TagObject> [acute, acute], <TagObject> [no, definite_negated_existence], <TagObject> [evidence, definite_existence], <TagObject> [new, acute], <TagObject> [Again, historical], <TagObject> [likely, probable_existence], <TagObject> [No, definite_negated_existence], <TagObject> [evidence, definite_existence]]
# [(infiltrate, <TagObject> [evidence, definite_existence]), (infiltrate, <TagObject> [new, acute]), (pneumonia, <TagObject> [evidence, definite_existence])]
#
# (pneumonia, effusions, pneumonia)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [clear, probable_negated_existence], <TagObject> [No, definite_negated_existence], <TagObject> [No, definite_negated_existence], <TagObject> [evidence, definite_existence], <TagObject> [No, definite_negated_existence], <TagObject> [No change, historical], <TagObject> [prior, historical], <TagObject> [prior study, historical], <TagObject> [study, indication]]
# [(effusions, <TagObject> [No, definite_negated_existence]), (pneumonia, <TagObject> [evidence, definite_existence])]
#
# (effusion,)
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [no, definite_negated_existence], <TagObject> [not, definite_negated_existence], <TagObject> [secondary to, conj], <TagObject> [is present, definite_existence], <TagObject> [clear, probable_negated_existence], <TagObject> [no, definite_negated_existence], <TagObject> [no significant, probable_negated_existence], <TagObject> [no significant interval change, historical], <TagObject> [interval change, historical]]
# [(effusion, <TagObject> [no, definite_negated_existence])]
#
# ()
# [<TagObject> [old, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [old, historical], <TagObject> [again, historical], <TagObject> [not, definite_negated_existence], <TagObject> [not significantly changed, historical], <TagObject> [not significantly changed, historical], <TagObject> [prior, historical], <TagObject> [prior study, historical], <TagObject> [study, indication], <TagObject> [not, definite_negated_existence], <TagObject> [however, conj], <TagObject> [Again, historical], <TagObject> [consistent with, definite_existence], <TagObject> [resolving, historical], <TagObject> [not, definite_negated_existence], <TagObject> [not changed, historical], <TagObject> [prior, historical], <TagObject> [exam, indication], <TagObject> [no, definite_negated_existence]]
# []
#
# (infiltrates, effusions, consolidation, pneumonia)
# [<TagObject> [old, historical], <TagObject> [known, historical], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [not, definite_negated_existence], <TagObject> [No, definite_negated_existence], <TagObject> [consistent with, definite_existence], <TagObject> [possible, probable_existence]]
# [(infiltrates, <TagObject> [old, historical]), (infiltrates, <TagObject> [known, historical]), (pneumonia, <TagObject> [consistent with, definite_existence]), (pneumonia, <TagObject> [possible, probable_existence])]
#
# (effusions, effusions)
# [<TagObject> [old, historical], <TagObject> [acute, acute], <TagObject> [REASON FOR, conj], <TagObject> [REASON FOR THIS EXAMINATION, indication], <TagObject> [EXAMINATION, indication], <TagObject> [INDICATION, indication], <TagObject> [unchanged, historical], <TagObject> [interval increase, historical], <TagObject> [increase, historical], <TagObject> [increase, historical], <TagObject> [Increased, historical], <TagObject> [Increased, historical], <TagObject> [No, definite_negated_existence], <TagObject> [unchanged, historical], <TagObject> [Interval increase, historical], <TagObject> [increase, historical], <TagObject> [increase, historical], <TagObject> [Stable, historical]]
# [(effusions, <TagObject> [Increased, historical]), (effusions, <TagObject> [Increased, historical]), (effusions, <TagObject> [increase, historical]), (effusions, <TagObject> [increase, historical])]

# %% [markdown]
# # Visualization

# %%
from cycontext import viz

# %%
from spacy import displacy

# %%
doc = docs[12]

# %%
doc._.context_graph.modifiers
# Out:
# [<TagObject> [Reason, indication],
#  <TagObject> [old, historical],
#  <TagObject> [signs of, probable_existence],
#  <TagObject> [exam, indication],
#  <TagObject> [REASON, indication],
#  <TagObject> [REASON FOR, conj],
#  <TagObject> [REASON FOR THIS EXAMINATION, indication],
#  <TagObject> [EXAMINATION, indication],
#  <TagObject> [previous, historical],
#  <TagObject> [prior, historical],
#  <TagObject> [increased, historical],
#  <TagObject> [increased, historical],
#  <TagObject> [involving, conj],
#  <TagObject> [history of, historical],
#  <TagObject> [worrisome, probable_existence],
#  <TagObject> [chronic, historical],
#  <TagObject> [evaluation, indication],
#  <TagObject> [could represent, probable_existence],
#  <TagObject> [no, definite_negated_existence],
#  <TagObject> [evidence, definite_existence],
#  <TagObject> [No, definite_negated_existence],
#  <TagObject> [Increased, historical],
#  <TagObject> [Increased, historical],
#  <TagObject> [involving, conj]]

# %%
doc._.context_graph.edges
# Out:
# []

# %%
doc = list(nlp.pipe(["Reason for this examination: infiltrate"], component_cfg=cfg))[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-152-5cf3424a81c1> in <module>
# ----> 1 doc = list(nlp.pipe(["Reason for this examination: infiltrate"], component_cfg=cfg))[0]
#
# ~/anaconda/envs/cycontext/lib/python3.7/site-packages/spacy/language.py in pipe(self, texts, as_tuples, n_threads, batch_size, disable, cleanup, component_cfg, n_process)
#     813         original_strings_data = None
#     814         nr_seen = 0
# --> 815         for doc in docs:
#     816             yield doc
#     817             if cleanup:
#
# ~/anaconda/envs/cycontext/lib/python3.7/site-packages/spacy/language.py in _pipe(docs, proc, kwargs)
#    1102         if arg in kwargs:
#    1103             kwargs.pop(arg)
# -> 1104     for doc in docs:
#    1105         doc = proc(doc, **kwargs)
#    1106         yield doc
#
# ~/anaconda/envs/cycontext/lib/python3.7/site-packages/spacy/language.py in _pipe(docs, proc, kwargs)
#    1103             kwargs.pop(arg)
#    1104     for doc in docs:
# -> 1105         doc = proc(doc, **kwargs)
#    1106         yield doc
#    1107
#
# ~/anaconda/envs/cycontext/lib/python3.7/site-packages/spacy/pipeline/entityruler.py in __call__(self, doc)
#     113                             token.ent_id_ = ent_id
#     114                 else:
# --> 115                     span = Span(doc, start, end, label=match_id)
#     116                 new_entities.append(span)
#     117                 entities = [
#
# span.pyx in spacy.tokens.span.Span.__cinit__()
#
# ValueError: [E084] Error assigning label ID 5227382582633743683 to span: not in StringStore.

# %%
viz.visualize_targets(doc
                     , colors ={"EVIDENCE_OF_PNEUMONIA": "orange",
                                          "DEFINITE_NEGATED_EXISTENCE": "blue",
                               "indication": "yellow"})
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">Reason for this examination: infiltrate</div>

# %%
for sent in doc.sents:
    print("---", sent)
    print()
# Out:
# ---
#
#
#      DATE: [**2919-8-31**] 5:14 PM
#      CHEST (PA & LAT)                                                Clip # [**Clip Number (Radiology) 11222**]
#      Reason: infiltrate vs.
#
# --- pulmonary edema
#      ______________________________________________________________________________
#      UNDERLYING MEDICAL CONDITION:
#       50 year old man with cough and hemoptysis and now progressive O2 requirement,
#       signs of CHF on exam.
#
# --- PMH of MVR.
#
#
# --- REASON FOR THIS EXAMINATION:
#       infiltrate vs.
#
# --- pulmonary edema
#      ______________________________________________________________________________
#                                      FINAL REPORT
#      INDICATIONS:  Cough and hemoptysis.
#
#
#
# --- PA AND LATERAL CHEST:  Comparison is made to previous films from  [**2919-8-17**].
#
#
# --- The patient has prior MBR and median sternotomy.
#
#
#
# --- Note is made of increased nodular and linear opacities involving the right
#      upper lobe and left lower lobe.
#
# --- In this patient with HIV and history of
#      chemotherapy for seminoma, these findings are worrisome for chronic infection
#      including fungus or microbacterial infection.
#
# --- Further evaluation with CT scan
#      is recommended.
#
# --- There is slight prominence of the left hilum.
#
# --- The patchy
#      opacity in the left lower lobe could represent bronchopneumonia.
#
# --- The heart
#      is normal in size.
#
# --- There is no evidence for CHF.
#
# --- No pneumothorax is
#      identified.
#
#
#
# --- IMPRESSION:  Increased nausea and linear opacities involving the right upper
#      lobe and left lower lobe, please see comment for discussion.

# %%
viz.visualize_modifiers(
    nlp("The patchy opacity in the left lower lobe could represent bronchopneumonia.",component_cfg=component_cfg))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-81e22d589db3> in <module>
# ----> 1 viz.visualize_modifiers(nlp("The patchy opacity in the left lower lobe could represent bronchopneumonia.",component_cfg=component_cfg))
#
# ~/anaconda/envs/cycontext/lib/python3.7/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     433             if not hasattr(proc, "__call__"):
#     434                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 435             doc = proc(doc, **component_cfg.get(name, {}))
#     436             if doc is None:
#     437                 raise ValueError(Errors.E005.format(name=name))
#
# TypeError: set_custom_boundaries() got an unexpected keyword argument 'batch_size'
